# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
from pandas import Series
import random
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy import eye, asarray, dot, sum, diag
from scipy.linalg import svd, svdvals
from mpl_toolkits.basemap import Basemap
import matplotlib as mpl
from matplotlib import cm
from colorspacious import cspace_converter
from collections import OrderedDict
from netCDF4 import Dataset
from numpy import linspace
from numpy import meshgrid
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import grangercausalitytests

import PCA_functions as pf
import Extreme_functions as ef

from tigramite import plotting as tp
from tigramite.pcmci import PCMCI
from tigramite.independence_tests import ParCorr, CMIknn
import tigramite.data_processing as pp

from statsmodels.tsa.stattools import adfuller
from Data import Data
from datetime import datetime

import itertools
from collections import Counter
import pickle

from numpy import linalg as LA

import matplotlib.cm as cm

import scipy.stats as st

import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd
from pandas import Series
import random
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy import eye, asarray, dot, sum, diag
from scipy.linalg import svd, svdvals
from mpl_toolkits.basemap import Basemap
import matplotlib as mpl
from matplotlib import cm
from colorspacious import cspace_converter
from collections import OrderedDict
from netCDF4 import Dataset
from numpy import linspace
from numpy import meshgrid
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.stattools import grangercausalitytests

import PCA_functions as pf
import Extreme_functions as ef

from tigramite import plotting as tp
from tigramite.pcmci import PCMCI
from tigramite.independence_tests import ParCorr, CMIknn
import tigramite.data_processing as pp

from statsmodels.tsa.stattools import adfuller
from Data import Data
from datetime import datetime

import itertools
from collections import Counter
import pickle

from numpy import linalg as LA

import matplotlib.cm as cm

import scipy.stats as st

#import reverse_geocoder as rg

from pandas_datareader import wb
import scipy.stats as st

plt.rcParams["figure.figsize"] = (5,5)

import seaborn as sns

from sklearn import preprocessing

import seaborn as sns

plt.rcParams["figure.figsize"] = (20,10)

import Rung as rg

from pandas_datareader import wb
import scipy.stats as st

plt.rcParams["figure.figsize"] = (5,5)

import seaborn as sns

from sklearn import preprocessing

import seaborn as sns

plt.rcParams["figure.figsize"] = (20,10)

# %%
def deseasonalize(data,freq=12):
    """
    The shape of data should be (time, index) 
    """
    n  = data.shape[1]
    N  = data.shape[0]
    data_deseasonal = np.zeros(data.shape)
    for i in range(n):
        temp = np.copy(data[:,i])
        temp = np.ravel(temp)
        r = np.zeros((N))
        for j in range(freq):
            Idx = np.arange(j,N,freq)
            if temp[Idx].std() == 0:
                r[Idx] = 0
            else:
                r[Idx] = (temp[Idx] - temp[Idx].mean())/temp[Idx].std()
        data_deseasonal[:,i] = np.copy(r)
    return(data_deseasonal)


def save_obj(obj, name ):
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def spiParametersMle(x, dist=st.gamma):
    i = x == 0
    params = dist.fit(x[~i])
    q = len(x[i])/len(x)
    return(params, q)

def spiGeneratorMle(x, dist=st.gamma):
    i = x == 0

    params = dist.fit(x[~i])
    arg = params[:-2]
    loc = params[-2]
    scale = params[-1]
    G = dist.cdf(x[~i], loc=loc, scale=scale, *arg)

    q = len(x[i])/len(x)
    probabilities = np.zeros(len(x))
    probabilities[i] = q
    probabilities[~i] = q + (1 - q) * G
    result = st.norm.ppf(probabilities)
    return(result)

def spiGeneratorParamMle(x, params, q, dist=st.gamma):
    i = x == 0
    arg = params[:-2]
    loc = params[-2]
    scale = params[-1]
    G = dist.cdf(x[~i], loc=loc, scale=scale, *arg)

    if G == 1: G = 0.99
    probabilities = np.zeros(len(x))
    probabilities[i] = q
    probabilities[~i] = q + (1 - q) * G

    result = st.norm.ppf(probabilities)
    return(result)


def phase_averaging(data,freq = 12):
    N = len(data)
    temp = data
    result = np.zeros(N)
    averages = np.zeros(freq)
    for j in range(freq):
        Idx = np.arange(j,N,freq)
        averages[j] = temp[Idx].mean()
        result[Idx] = (temp[Idx] - temp[Idx].mean())/temp[Idx].std()
    return(result, averages)

def deseasonalize_NoStd(data,freq=12):
    n  = data.shape[1]
    N  = data.shape[0]
    averages = np.zeros((freq,n))
    data_deseasonal = np.zeros(data.shape)
    for i in range(n):
        temp = data[:,i]
        result = np.zeros((N))
        for j in range(freq):
            Idx = np.arange(j,N,freq)
            averages[j,i] = temp[Idx].mean()
            result[Idx] = temp[Idx] - temp[Idx].mean()
        data_deseasonal[:,i] = result
    return(data_deseasonal,averages)


def crosscorr(datax, datay, lag=0):
    """ Lag-N cross correlation. 
    Parameters
    ----------
    lag : int, default 0
    datax, datay : pandas.Series objects of equal length

    Returns
    ----------
    crosscorr : float
    """
    return datax.corr(datay.shift(lag))


def deseasonalize1(data,freq=12):
    """
    The shape of data should be (time, index) 
    """
    n  = data.shape[1]
    t  = data.shape[0]
    N = t - 360
    data_deseasonal = np.zeros((N,n))
    for i in range(n):
        temp = np.copy(data[360:,i])
        temp1 = np.copy(data[:360,i])
        temp = np.ravel(temp)
        temp1 = np.ravel(temp1)
        r = np.zeros((N))
        for j in range(freq):
            Idx = np.arange(j,360,freq)
            Idx1 = np.arange(j,N,freq)
            if temp1[Idx].std() == 0:
                r[Idx1] = 0
            else:
                r[Idx1] = (temp[Idx1] - temp1[Idx].mean())/temp1[Idx].std()
        data_deseasonal[:,i] = np.copy(r)
    return(data_deseasonal)


def deseasonalize2(data,freq=12, ref_period = 360):
    """
    The shape of data should be (time, index) 
    """
    n  = data.shape[1]
    t  = data.shape[0]
    N = t - ref_period
    r = np.zeros((N))
    data_deseasonal = np.zeros((N,n))
    for i in range(n):
        for j in range(ref_period,t):
            d = data[j,i]
            temp = np.copy(data[j-ref_period:j,i])
            temp = np.ravel(temp)
            Idx = np.arange(0,ref_period,freq)
            if temp[Idx].std() == 0:
                r[j] = 0
            else:
                r[j] = (d - temp[Idx].mean())/temp[Idx].std()
        data_deseasonal[:,i] = np.copy(r)
    return(data_deseasonal)

# %%
level = 12
temporal_limits = {"time_min":datetime(1977, 1, 1, 0, 0),"time_max":datetime(2015, 12, 1, 0, 0)}

# %%
n_components_sst = 76

sst = Data('../../nc/sst.mnmean.nc','sst',temporal_limits, missing_value= -9.96921e+36)

result_raw = sst.get_data()
lon_sst_list = sst.get_lon_list()
lat_sst_list = sst.get_lat_list()
lon_sst = sst.get_lon()
lat_sst = sst.get_lat()

result_sst = pf.deseasonalize(np.array(result_raw))
weights = np.sqrt(np.abs(np.cos(np.array(lat_sst_list)* math.pi/180)))
for i in range(len(weights)):
    result_sst[:,i] = weights[i] * result_sst[:,i]

data_sst = pd.DataFrame(result_sst)

V, U, S, ts, eig, explained, max_comps = rg.pca_svd(data_sst,truncate_by='max_comps', max_comps=n_components_sst)

Vr, Rot = rg.varimax(V)
Vr = rg.svd_flip(Vr)

# Get explained variance of rotated components
s2 = np.diag(S)**2 / (ts.shape[0] - 1.)

# matrix with diagonal containing variances of rotated components
S2r = np.dot(np.dot(np.transpose(Rot), np.matrix(np.diag(s2))), Rot)
expvar = np.diag(S2r)

sorted_expvar = np.sort(expvar)[::-1]
# s_orig = ((Vt.shape[1] - 1) * s2) ** 0.5

# reorder all elements according to explained variance (descending)
nord = np.argsort(expvar)[::-1]
Vr = Vr[:, nord]

# Get time series of UNMASKED data
comps_ts = np.matmul(np.array(data_sst),Vr)

df_sst = pd.DataFrame({"lons":lon_sst_list,"lats":lat_sst_list})

lon_temp = df_sst["lons"].values
lon_temp[lon_temp > 180] = lon_temp[lon_temp > 180] -360
df_sst["lons"].vlues = lon_temp

# %%
n_components_sst = 76

sst = Data('../../nc/sst.mnmean.nc','sst',temporal_limits, missing_value= -9.96921e+36)

result_raw = sst.get_data()
lon_sst_list = sst.get_lon_list()
lat_sst_list = sst.get_lat_list()
lon_sst = sst.get_lon()
lat_sst = sst.get_lat()

result_sst = pf.deseasonalize(np.array(result_raw))
weights = np.sqrt(np.abs(np.cos(np.array(lat_sst_list)* math.pi/180)))
for i in range(len(weights)):
    result_sst[:,i] = weights[i] * result_sst[:,i]

data_sst = pd.DataFrame(result_sst)

V, U, S, ts, eig, explained, max_comps = rg.pca_svd(data_sst,truncate_by='max_comps', max_comps=n_components_sst)

Vr, Rot = rg.varimax(V)
Vr = rg.svd_flip(Vr)

# Get explained variance of rotated components
s2 = np.diag(S)**2 / (ts.shape[0] - 1.)

# matrix with diagonal containing variances of rotated components
S2r = np.dot(np.dot(np.transpose(Rot), np.matrix(np.diag(s2))), Rot)
expvar = np.diag(S2r)

sorted_expvar = np.sort(expvar)[::-1]
# s_orig = ((Vt.shape[1] - 1) * s2) ** 0.5

# reorder all elements according to explained variance (descending)
nord = np.argsort(expvar)[::-1]
Vr = Vr[:, nord]

# Get time series of UNMASKED data
comps_ts = np.matmul(np.array(data_sst),Vr)

loading_sst = pf.varimax(V, q=1000)
loading_sst = rg.svd_flip(loading_sst)
for z in range(loading_sst.shape[1]):
    loading_sst[:,z] = loading_sst[:,z] / np.linalg.norm(loading_sst[:,z])
    
loading_sst = pd.DataFrame(loading_sst)


df_sst = pd.DataFrame({"lons":lon_sst_list,"lats":lat_sst_list})

lon_temp = df_sst["lons"].values
lon_temp[lon_temp > 180] = lon_temp[lon_temp > 180] -360
df_sst["lons"].vlues = lon_temp

# %%
pc = 40

# %%
df_sst["pc"] = V[:,pc]

#lon1 = np.arange(-178.75,179.0,2.5)
lon1_sst = np.arange(-180,180,2)
#lat1 = np.arange(-40,40,2.5)

deg = np.zeros((len(lat_sst),len(lon1_sst)))

lat_number = deg.shape[0]
lon_number = deg.shape[1]

for i in range(lat_number):
    for j in range(lon_number):
        if not df_sst[(df_sst.lats == lat_sst[i]) & (df_sst.lons == lon1_sst[j])].pc.values.size == 0:
            deg[i,j] = df_sst[(df_sst.lats == lat_sst[i]) & (df_sst.lons == lon1_sst[j])].pc.values
        else:
            deg[i,j]=np.nan


plt.figure(figsize=(30,15))
# Make the background map
#map=Basemap(llcrnrlon=lon1[0], llcrnrlat=lat[-1],urcrnrlon=lon1[-1],urcrnrlat=lat[0])
map = Basemap(llcrnrlon=-180, llcrnrlat=-65,urcrnrlon=180,urcrnrlat=80)
#m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
map.fillcontinents(color='grey', alpha=0.5)
#m.drawcoastlines(linewidth=0.1, color="white")
#map.drawparallels(np.arange(int(-39.75),int(39.75),3),labels=[1,0,0,0],linewidth=0.5)
#map.drawmeridians(np.arange(int(-29.75),int(59.75),3),labels=[0,0,0,1],linewidth=0.5)
map.drawcoastlines(linewidth=0.)


xx, yy = meshgrid(lon1_sst, lat_sst)
cs = map.pcolormesh(xx, yy, deg, cmap=plt.cm.Spectral_r)
#cs = map.contourf(xx, yy, deg, 11, cmap=plt.cm.Spectral_r)
cbar = plt.colorbar(cs, orientation='horizontal', shrink=0.5)
cbar.ax.tick_params(labelsize=35)
#plt.clim(-0.1,0.1)
#cbar.set_label('Loadings', fontsize = )
#plt.title("Sea Surface Temperature EOF %d"%(pc+1),fontsize = 40)
#plt.savefig("SST EOF%d_unrotated.png"%(pc+1))
plt.show()
# Out:
# /home/mathsys2/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %%
df_sst["pc"] = V[:,pc]

if np.abs(df_sst.pc.values.min()) > np.abs(df_sst.pc.values.max()):
    limit = np.percentile(df_sst.pc.values, 5)
    df_sst.pc.values[df_sst.pc.values>=limit]=np.nan
else:
    limit = np.percentile(df_sst.pc.values, 95)
    df_sst.pc.values[df_sst.pc.values<=limit]=np.nan
    
df_sst.pc.values[df_sst.pc.values<=limit]=np.nan

I = np.where(~np.isnan(df_sst.pc.values))

df_sst1 = df_sst.iloc[I]

#pc = 1
#df_sst["pc"] = loading_sst[pc]


#lon1 = np.arange(-178.75,179.0,2.5)
lon1_sst = np.arange(-180,180,2)
#lat1 = np.arange(-40,40,2.5)

deg = np.zeros((len(lat_sst),len(lon1_sst)))

lat_number = deg.shape[0]
lon_number = deg.shape[1]

for i in range(lat_number):
    for j in range(lon_number):
        if not df_sst1[(df_sst1.lats == lat_sst[i]) & (df_sst1.lons == lon1_sst[j])].pc.values.size == 0:
            deg[i,j] = df_sst1[(df_sst1.lats == lat_sst[i]) & (df_sst1.lons == lon1_sst[j])].pc.values
        else:
            deg[i,j]=np.nan


plt.figure(figsize=(30,15))
map = Basemap(llcrnrlon=-180, llcrnrlat=-65,urcrnrlon=180,urcrnrlat=80)
map.fillcontinents(color='grey', alpha=0.5)
map.drawcoastlines(linewidth=0.)


xx, yy = meshgrid(lon1_sst, lat_sst)
cs = map.pcolormesh(xx, yy, deg, cmap=plt.cm.Spectral_r)
cbar = plt.colorbar(cs, orientation='horizontal', shrink=0.5)
cbar.ax.tick_params(labelsize=35)
#plt.clim(-0.1,0.1)
#cbar.set_label('Loadings', fontsize = )
#plt.title("Sea Surface Temperature EOF %d"%(pc+1),fontsize = 40)
#plt.savefig("SST EOF%d_unrotated.png"%(pc+1))
plt.show()
# Out:
# /home/mathsys2/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in less_equal
#   # Remove the CWD from sys.path while we load stuff.
# /home/mathsys2/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %%
df_sst["pc"] = loading_sst[pc]

#lon1 = np.arange(-178.75,179.0,2.5)
lon1_sst = np.arange(-180,180,2)
#lat1 = np.arange(-40,40,2.5)

deg = np.zeros((len(lat_sst),len(lon1_sst)))

lat_number = deg.shape[0]
lon_number = deg.shape[1]

for i in range(lat_number):
    for j in range(lon_number):
        if not df_sst[(df_sst.lats == lat_sst[i]) & (df_sst.lons == lon1_sst[j])].pc.values.size == 0:
            deg[i,j] = df_sst[(df_sst.lats == lat_sst[i]) & (df_sst.lons == lon1_sst[j])].pc.values
        else:
            deg[i,j]=np.nan


plt.figure(figsize=(30,15))
# Make the background map
#map=Basemap(llcrnrlon=lon1[0], llcrnrlat=lat[-1],urcrnrlon=lon1[-1],urcrnrlat=lat[0])
map = Basemap(llcrnrlon=-180, llcrnrlat=-65,urcrnrlon=180,urcrnrlat=80)
#m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
map.fillcontinents(color='grey', alpha=0.5)
#m.drawcoastlines(linewidth=0.1, color="white")
#map.drawparallels(np.arange(int(-39.75),int(39.75),3),labels=[1,0,0,0],linewidth=0.5)
#map.drawmeridians(np.arange(int(-29.75),int(59.75),3),labels=[0,0,0,1],linewidth=0.5)
map.drawcoastlines(linewidth=0.)


xx, yy = meshgrid(lon1_sst, lat_sst)
cs = map.pcolormesh(xx, yy, deg, cmap=plt.cm.Spectral_r)
#cs = map.contourf(xx, yy, deg, 11, cmap=plt.cm.Spectral_r)
cbar = plt.colorbar(cs, orientation='horizontal', shrink=0.5)
cbar.ax.tick_params(labelsize=35)
#plt.clim(-0.1,0.1)
#cbar.set_label('Loadings', fontsize = )
#plt.title("Sea Surface Temperature EOF %d"%(pc+1),fontsize = 40)
#plt.savefig("SST EOF%d_unrotated.png"%(pc+1))
plt.show()
# Out:
# /home/mathsys2/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %%
ET_gamma = np.load("ET_gamma.npy")
N = ET_gamma.shape[0]
n_nodes = ET_gamma.shape[1]
extremes_treshold = -1
count = []
for i in range(N):
    count.append(np.count_nonzero(ET_gamma[i,:] <= extremes_treshold))

# %%
result_ = np.zeros(n_components_sst)
for pc in range(n_components_sst):
    df_sst["pc"] = V[:,pc]
    if np.abs(df_sst.pc.values.min()) > np.abs(df_sst.pc.values.max()):
        limit = np.percentile(df_sst.pc.values, 5)
        d = df_sst[df_sst.pc.values < limit]
    else:
        limit = np.percentile(df_sst.pc.values, 95)
        d = df_sst[df_sst.pc.values > limit]
    #limit = np.percentile(df_sst.pc.values, 95)
    #d = df_sst[df_sst.pc > limit]
    d = result_raw[:,d.index].mean(axis=1)
    d = np.ravel(d)
    d = np.reshape(d,(len(d),1))
    d = pf.deseasonalize(d)
    d = np.ravel(d)
    
    p = np.zeros(4)
    df = pd.DataFrame({"drought":count, "sst":d})
    r = grangercausalitytests(df,maxlag=12,  verbose=False)
    month = np.zeros(12)
    for i in range(1,13):
        p[0] = r[i][0]['lrtest'][1]
        p[1] = r[i][0]['params_ftest'][1]
        p[2] = r[i][0]['ssr_chi2test'][1]
        p[3] = r[i][0]['ssr_ftest'][1]
    
        if np.all(p <0.05): month[i-1] = 1
    if len(np.where(month == 1)[0]) > 0:        
        result_[pc] = np.where(month == 1)[0][-1]

# %%
I  = np.where(result_ >0)[0]

# %%
for i in range(len(I)):
    print("SST {} with lag of {} months ".format(I[i],int(result_[I][i])))
# Out:
# SST 0 with lag of 10 months
# SST 1 with lag of 11 months
# SST 9 with lag of 2 months
# SST 15 with lag of 10 months
# SST 21 with lag of 10 months
# SST 34 with lag of 7 months
# SST 37 with lag of 6 months
# SST 54 with lag of 11 months
# SST 69 with lag of 8 months

# %%
file_name = 'result_dic_test_ET2.txt'
with open(file_name, 'r') as f:
    Lines = f.readlines()
    
result_repeats = {}
for Line in Lines:
    line = Line.strip().split(")")
    key = (int(line[0].split(',')[0][1:]), int(line[0].split(',')[1].strip()))
    value = int(line[1].strip(","))
    if value >= 95:
        result_repeats[key] = value

# %%
for key in result_repeats.keys():
    if key[0]!=0:
        print("SST {} with lag of {} months, # the occurrences of {} out of 100".format(key[0]-1,key[1],result_repeats[key]))
# Out:
# SST 11 with lag of -4 months, # the occurrences of 96 out of 100
# SST 1 with lag of -9 months, # the occurrences of 96 out of 100
# SST 33 with lag of -11 months, # the occurrences of 98 out of 100
# SST 34 with lag of -10 months, # the occurrences of 96 out of 100
# SST 28 with lag of -2 months, # the occurrences of 99 out of 100
# SST 32 with lag of -1 months, # the occurrences of 97 out of 100
# SST 1 with lag of -7 months, # the occurrences of 100 out of 100
# SST 14 with lag of -3 months, # the occurrences of 95 out of 100
# SST 34 with lag of -1 months, # the occurrences of 98 out of 100
# SST 9 with lag of -12 months, # the occurrences of 95 out of 100
# SST 23 with lag of -4 months, # the occurrences of 100 out of 100

# %%
for key in result_repeats.keys():
    if key[0]!=0:
        print("SST {} with lag of {} months, # the occurrences of {} out of 100".format(key[0]-1,key[1],result_repeats[key]))
# Out:
# SST 25 with lag of -5 months, # the occurrences of 100 out of 100
# SST 0 with lag of -10 months, # the occurrences of 100 out of 100
# SST 1 with lag of -9 months, # the occurrences of 98 out of 100
# SST 33 with lag of -11 months, # the occurrences of 100 out of 100
# SST 15 with lag of -8 months, # the occurrences of 98 out of 100
# SST 1 with lag of -12 months, # the occurrences of 100 out of 100
# SST 1 with lag of -7 months, # the occurrences of 100 out of 100
# SST 26 with lag of -3 months, # the occurrences of 98 out of 100
# SST 34 with lag of -1 months, # the occurrences of 100 out of 100
# SST 9 with lag of -12 months, # the occurrences of 100 out of 100
# SST 23 with lag of -4 months, # the occurrences of 100 out of 100

# %%
pc = 25
df_sst["pc"] = loading_sst[pc]


#lon1 = np.arange(-178.75,179.0,2.5)
lon1_sst = np.arange(-180,180,2)
#lat1 = np.arange(-40,40,2.5)

deg = np.zeros((len(lat_sst),len(lon1_sst)))

lat_number = deg.shape[0]
lon_number = deg.shape[1]

for i in range(lat_number):
    for j in range(lon_number):
        if not df_sst[(df_sst.lats == lat_sst[i]) & (df_sst.lons == lon1_sst[j])].clusters.values.size == 0:
            deg[i,j] = df_sst[(df_sst.lats == lat_sst[i]) & (df_sst.lons == lon1_sst[j])].pc.values
        else:
            deg[i,j]=np.nan


plt.figure(figsize=(30,15))
# Make the background map
#map=Basemap(llcrnrlon=lon1[0], llcrnrlat=lat[-1],urcrnrlon=lon1[-1],urcrnrlat=lat[0])
map = Basemap(llcrnrlon=-180, llcrnrlat=-65,urcrnrlon=180,urcrnrlat=80)
#m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
map.fillcontinents(color='grey', alpha=0.5)
#m.drawcoastlines(linewidth=0.1, color="white")
#map.drawparallels(np.arange(int(-39.75),int(39.75),3),labels=[1,0,0,0],linewidth=0.5)
#map.drawmeridians(np.arange(int(-29.75),int(59.75),3),labels=[0,0,0,1],linewidth=0.5)
map.drawcoastlines(linewidth=0.)


xx, yy = meshgrid(lon1_sst, lat_sst)
cs = map.pcolormesh(xx, yy, deg, cmap=plt.cm.Spectral_r)
#cs = map.contourf(xx, yy, deg, 11, cmap=plt.cm.Spectral_r)
cbar = plt.colorbar(cs, orientation='horizontal', shrink=0.5)
cbar.ax.tick_params(labelsize=35)
#plt.clim(-0.1,0.1)
#cbar.set_label('Loadings', fontsize = )
#plt.title("Sea Surface Temperature EOF %d"%(pc+1),fontsize = 40)
#plt.savefig("SST EOF%d_unrotated.png"%(pc+1))
plt.show()
# Out:
# /home/mathsys2/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %%
pc = 26
df_sst["pc"] = loading_sst[pc]


#lon1 = np.arange(-178.75,179.0,2.5)
lon1_sst = np.arange(-180,180,2)
#lat1 = np.arange(-40,40,2.5)

deg = np.zeros((len(lat_sst),len(lon1_sst)))

lat_number = deg.shape[0]
lon_number = deg.shape[1]

for i in range(lat_number):
    for j in range(lon_number):
        if not df_sst[(df_sst.lats == lat_sst[i]) & (df_sst.lons == lon1_sst[j])].clusters.values.size == 0:
            deg[i,j] = df_sst[(df_sst.lats == lat_sst[i]) & (df_sst.lons == lon1_sst[j])].pc.values
        else:
            deg[i,j]=np.nan


plt.figure(figsize=(30,15))
# Make the background map
#map=Basemap(llcrnrlon=lon1[0], llcrnrlat=lat[-1],urcrnrlon=lon1[-1],urcrnrlat=lat[0])
map = Basemap(llcrnrlon=-180, llcrnrlat=-65,urcrnrlon=180,urcrnrlat=80)
#m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
map.fillcontinents(color='grey', alpha=0.5)
#m.drawcoastlines(linewidth=0.1, color="white")
#map.drawparallels(np.arange(int(-39.75),int(39.75),3),labels=[1,0,0,0],linewidth=0.5)
#map.drawmeridians(np.arange(int(-29.75),int(59.75),3),labels=[0,0,0,1],linewidth=0.5)
map.drawcoastlines(linewidth=0.)


xx, yy = meshgrid(lon1_sst, lat_sst)
cs = map.pcolormesh(xx, yy, deg, cmap=plt.cm.Spectral_r)
#cs = map.contourf(xx, yy, deg, 11, cmap=plt.cm.Spectral_r)
cbar = plt.colorbar(cs, orientation='horizontal', shrink=0.5)
cbar.ax.tick_params(labelsize=35)
#plt.clim(-0.1,0.1)
#cbar.set_label('Loadings', fontsize = )
#plt.title("Sea Surface Temperature EOF %d"%(pc+1),fontsize = 40)
#plt.savefig("SST EOF%d_unrotated.png"%(pc+1))
plt.show()
# Out:
# /home/mathsys2/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %%
result_extremes = np.array(count)
result_extremes = result_extremes.reshape((-1,1))

# %%
result_sst = np.array(df_cluster_sst[:,I])
result = np.concatenate((result_extremes,result_sst), axis=1)
result = np.array(result)

# %%
dataframe = pp.DataFrame(result)
cond_ind_test = ParCorr()
pcmci = PCMCI(dataframe=dataframe, cond_ind_test=cond_ind_test)

# %%
results = pcmci.run_pcmci(tau_max=12, pc_alpha=None)

# %%
pcmci.print_significant_links(p_matrix=results['p_matrix'],
                                     val_matrix=results['val_matrix'],
                                     alpha_level=0.05)
# Out:
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 16 link(s):
#         (0 -1): pval = 0.00000 | val = 0.644
#         (0 -12): pval = 0.00000 | val = -0.271
#         (1 -12): pval = 0.00111 | val = -0.159
#         (6 -12): pval = 0.00857 | val = 0.130
#         (9 -1): pval = 0.01092 | val = 0.126
#         (6 -6): pval = 0.01269 | val = 0.123
#         (3 0): pval = 0.01517 | val = -0.120
#         (0 -2): pval = 0.02067 | val = 0.114
#         (1 -7): pval = 0.02151 | val = -0.113
#         (0 -4): pval = 0.02705 | val = 0.109
#         (8 -9): pval = 0.03047 | val = -0.107
#         (9 -12): pval = 0.04505 | val = -0.100
#         (10 -9): pval = 0.04504 | val = -0.099
#         (8 -6): pval = 0.04654 | val = 0.098
#         (2 -6): pval = 0.04905 | val = -0.098
#         (1 -6): pval = 0.04800 | val = 0.097
#
#     Variable 1 has 8 link(s):
#         (1 -1): pval = 0.00000 | val = 0.786
#         (5 -6): pval = 0.00196 | val = 0.152
#         (9 -10): pval = 0.01115 | val = -0.126
#         (1 -2): pval = 0.01047 | val = -0.124
#         (6 -3): pval = 0.01948 | val = 0.115
#         (9 0): pval = 0.02053 | val = 0.115
#         (7 0): pval = 0.02778 | val = 0.108
#         (2 -2): pval = 0.04627 | val = 0.098
#
#     Variable 2 has 22 link(s):
#         (2 -1): pval = 0.00000 | val = 0.672
#         (1 -5): pval = 0.00025 | val = -0.179
#         (1 -1): pval = 0.00439 | val = -0.139
#         (3 0): pval = 0.00770 | val = 0.132
#         (1 -6): pval = 0.00775 | val = 0.131
#         (7 -4): pval = 0.00917 | val = -0.129
#         (5 -11): pval = 0.01048 | val = 0.127
#         (7 -12): pval = 0.01153 | val = -0.126
#         (10 -4): pval = 0.01114 | val = 0.125
#         (7 -5): pval = 0.01693 | val = 0.119
#         (8 -1): pval = 0.01721 | val = 0.118
#         (2 -3): pval = 0.02069 | val = -0.115
#         (8 -12): pval = 0.02834 | val = -0.109
#         (4 -6): pval = 0.02785 | val = -0.108
#         (5 -4): pval = 0.03181 | val = -0.107
#         (8 -7): pval = 0.03278 | val = 0.106
#         (2 -10): pval = 0.03323 | val = 0.106
#         (8 -8): pval = 0.03536 | val = -0.104
#         (4 -11): pval = 0.03580 | val = 0.104
#         (6 -1): pval = 0.03859 | val = 0.103
#         (6 -5): pval = 0.04659 | val = 0.099
#         (5 0): pval = 0.04580 | val = -0.099
#
#     Variable 3 has 10 link(s):
#         (3 -1): pval = 0.00000 | val = 0.650
#         (3 -4): pval = 0.00005 | val = 0.201
#         (7 -2): pval = 0.00546 | val = 0.138
#         (2 0): pval = 0.00770 | val = 0.132
#         (2 -10): pval = 0.00978 | val = 0.128
#         (2 -1): pval = 0.01475 | val = -0.121
#         (0 0): pval = 0.01517 | val = -0.120
#         (7 -6): pval = 0.02764 | val = -0.110
#         (0 -4): pval = 0.02754 | val = -0.109
#         (3 -2): pval = 0.03532 | val = -0.105
#
#     Variable 4 has 12 link(s):
#         (4 -1): pval = 0.00000 | val = 0.659
#         (10 -1): pval = 0.00172 | val = 0.154
#         (4 -2): pval = 0.00237 | val = -0.149
#         (9 0): pval = 0.00390 | val = -0.143
#         (1 -7): pval = 0.00405 | val = 0.141
#         (10 0): pval = 0.00530 | val = -0.136
#         (4 -11): pval = 0.01178 | val = 0.124
#         (5 -8): pval = 0.01231 | val = -0.124
#         (7 -12): pval = 0.02521 | val = -0.111
#         (9 -7): pval = 0.04722 | val = 0.099
#         (4 -3): pval = 0.04711 | val = 0.098
#         (5 -2): pval = 0.04860 | val = -0.097
#
#     Variable 5 has 10 link(s):
#         (5 -1): pval = 0.00000 | val = 0.649
#         (7 -10): pval = 0.00079 | val = 0.166
#         (9 -12): pval = 0.00118 | val = 0.162
#         (5 -2): pval = 0.00425 | val = -0.141
#         (7 -3): pval = 0.00517 | val = 0.139
#         (8 -12): pval = 0.00539 | val = -0.138
#         (2 -8): pval = 0.00642 | val = -0.135
#         (5 -5): pval = 0.03351 | val = 0.105
#         (1 -8): pval = 0.03447 | val = -0.104
#         (2 0): pval = 0.04580 | val = -0.099
#
#     Variable 6 has 7 link(s):
#         (6 -1): pval = 0.00000 | val = 0.589
#         (9 -10): pval = 0.00755 | val = -0.133
#         (0 -7): pval = 0.00773 | val = -0.132
#         (3 -8): pval = 0.00939 | val = -0.129
#         (9 -2): pval = 0.01765 | val = -0.118
#         (3 -12): pval = 0.03579 | val = 0.105
#         (5 -7): pval = 0.04899 | val = -0.098
#
#     Variable 7 has 11 link(s):
#         (7 -1): pval = 0.00000 | val = 0.623
#         (9 -1): pval = 0.00146 | val = 0.158
#         (7 -2): pval = 0.00146 | val = -0.158
#         (8 -2): pval = 0.00738 | val = -0.133
#         (1 -1): pval = 0.00822 | val = -0.130
#         (10 -3): pval = 0.01038 | val = 0.127
#         (8 -1): pval = 0.01229 | val = 0.124
#         (5 -2): pval = 0.01951 | val = 0.116
#         (1 0): pval = 0.02778 | val = 0.108
#         (5 -12): pval = 0.03804 | val = -0.103
#         (4 -1): pval = 0.03770 | val = -0.103
#
#     Variable 8 has 11 link(s):
#         (8 -1): pval = 0.00000 | val = 0.486
#         (8 -2): pval = 0.00188 | val = -0.153
#         (5 -5): pval = 0.00336 | val = 0.144
#         (4 -12): pval = 0.01233 | val = 0.123
#         (5 -8): pval = 0.01709 | val = 0.118
#         (6 -11): pval = 0.01974 | val = -0.116
#         (10 -9): pval = 0.01985 | val = 0.114
#         (7 -5): pval = 0.03083 | val = -0.107
#         (9 -11): pval = 0.03325 | val = -0.106
#         (4 -8): pval = 0.03626 | val = 0.103
#         (9 -5): pval = 0.04521 | val = 0.100
#
#     Variable 9 has 12 link(s):
#         (9 -1): pval = 0.00000 | val = 0.422
#         (9 -12): pval = 0.00017 | val = 0.188
#         (10 -3): pval = 0.00172 | val = -0.155
#         (4 0): pval = 0.00390 | val = -0.143
#         (9 -10): pval = 0.00611 | val = 0.137
#         (5 -1): pval = 0.01035 | val = -0.127
#         (4 -7): pval = 0.02098 | val = -0.115
#         (1 0): pval = 0.02053 | val = 0.115
#         (10 -12): pval = 0.02426 | val = -0.112
#         (10 -10): pval = 0.02421 | val = -0.112
#         (1 -6): pval = 0.03556 | val = 0.104
#         (6 -1): pval = 0.04412 | val = -0.100
#
#     Variable 10 has 5 link(s):
#         (10 -1): pval = 0.00000 | val = 0.449
#         (3 -12): pval = 0.00409 | val = 0.142
#         (9 -9): pval = 0.00479 | val = -0.140
#         (4 0): pval = 0.00530 | val = -0.136
#         (10 -10): pval = 0.01477 | val = -0.120

# %%
q_matrix = pcmci.get_corrected_pvalues(p_matrix=results['p_matrix'], fdr_method='fdr_bh')
pcmci.print_significant_links(
        p_matrix = results['p_matrix'], 
        q_matrix = q_matrix,
        val_matrix = results['val_matrix'],
        alpha_level = 0.05)
# Out:
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 3 link(s):
#         (0 -1): pval = 0.00000 | qval = 0.00000 | val = 0.644
#         (0 -12): pval = 0.00000 | qval = 0.00000 | val = -0.271
#         (3 0): pval = 0.01517 | qval = 0.01517 | val = -0.120
#
#     Variable 1 has 3 link(s):
#         (1 -1): pval = 0.00000 | qval = 0.00000 | val = 0.786
#         (9 0): pval = 0.02053 | qval = 0.02053 | val = 0.115
#         (7 0): pval = 0.02778 | qval = 0.02778 | val = 0.108
#
#     Variable 2 has 4 link(s):
#         (2 -1): pval = 0.00000 | qval = 0.00000 | val = 0.672
#         (1 -5): pval = 0.00025 | qval = 0.02411 | val = -0.179
#         (3 0): pval = 0.00770 | qval = 0.00770 | val = 0.132
#         (5 0): pval = 0.04580 | qval = 0.04580 | val = -0.099
#
#     Variable 3 has 4 link(s):
#         (3 -1): pval = 0.00000 | qval = 0.00000 | val = 0.650
#         (3 -4): pval = 0.00005 | qval = 0.00521 | val = 0.201
#         (2 0): pval = 0.00770 | qval = 0.00770 | val = 0.132
#         (0 0): pval = 0.01517 | qval = 0.01517 | val = -0.120
#
#     Variable 4 has 3 link(s):
#         (4 -1): pval = 0.00000 | qval = 0.00000 | val = 0.659
#         (9 0): pval = 0.00390 | qval = 0.00390 | val = -0.143
#         (10 0): pval = 0.00530 | qval = 0.00530 | val = -0.136
#
#     Variable 5 has 2 link(s):
#         (5 -1): pval = 0.00000 | qval = 0.00000 | val = 0.649
#         (2 0): pval = 0.04580 | qval = 0.04580 | val = -0.099
#
#     Variable 6 has 1 link(s):
#         (6 -1): pval = 0.00000 | qval = 0.00000 | val = 0.589
#
#     Variable 7 has 2 link(s):
#         (7 -1): pval = 0.00000 | qval = 0.00000 | val = 0.623
#         (1 0): pval = 0.02778 | qval = 0.02778 | val = 0.108
#
#     Variable 8 has 1 link(s):
#         (8 -1): pval = 0.00000 | qval = 0.00000 | val = 0.486
#
#     Variable 9 has 4 link(s):
#         (9 -1): pval = 0.00000 | qval = 0.00000 | val = 0.422
#         (9 -12): pval = 0.00017 | qval = 0.01779 | val = 0.188
#         (4 0): pval = 0.00390 | qval = 0.00390 | val = -0.143
#         (1 0): pval = 0.02053 | qval = 0.02053 | val = 0.115
#
#     Variable 10 has 2 link(s):
#         (10 -1): pval = 0.00000 | qval = 0.00000 | val = 0.449
#         (4 0): pval = 0.00530 | qval = 0.00530 | val = -0.136

# %%
save_obj(results, "results_ET_scaled_scaled5")

q_matrix = pcmci.get_corrected_pvalues(p_matrix=results['p_matrix'], fdr_method='fdr_bh')
np.save("q_matrix_ET_scaled_scaled5.npy",q_matrix)
#pcmci.print_significant_links(
#        p_matrix = results['p_matrix'], 
#        q_matrix = q_matrix,
#        val_matrix = results['val_matrix'],
#       alpha_level = 0.05)

# %%
n_components_sst = 76

sst = Data('../../nc/sst.mnmean.nc','sst',temporal_limits, missing_value= -9.96921e+36)

result_raw = sst.get_data()
lon_sst_list = sst.get_lon_list()
lat_sst_list = sst.get_lat_list()
lon_sst = sst.get_lon()
lat_sst = sst.get_lat()

result_sst = pf.deseasonalize(np.array(result_raw))
weights = np.sqrt(np.abs(np.cos(np.array(lat_sst_list)* math.pi/180)))
for i in range(len(weights)):
    result_sst[:,i] = weights[i] * result_sst[:,i]

data_sst = pd.DataFrame(result_sst)


scale = StandardScaler()
scaled_data = scale.fit_transform(data_sst)

pca = PCA(n_components=n_components_sst)
#pca_model = pca.fit(scaled_data)
pca_model = pca.fit(data_sst)
#df_cluster_sst = pca_model.transform(scaled_data)
df_cluster_sst = pca_model.transform(data_sst)


loading_sst = pf.varimax(np.transpose(pca_model.components_), q=1000)
loading_sst = rg.svd_flip(loading_sst)
for z in range(loading_sst.shape[1]):
    loading_sst[:,z] = loading_sst[:,z] / np.linalg.norm(loading_sst[:,z])
    
loading_sst = pd.DataFrame(loading_sst)
    
loading_sst_U = np.transpose(pca_model.components_)    
loading_sst_U = pd.DataFrame(loading_sst_U)


clusters = loading_sst.idxmax(axis=1)
df_sst = pd.DataFrame({"lons":lon_sst_list,"lats":lat_sst_list,"clusters":clusters.values.tolist()})

lon_temp = df_sst["lons"].values
lon_temp[lon_temp > 180] = lon_temp[lon_temp > 180] -360
df_sst["lons"].vlues = lon_temp

# %%
r = []

for i in range(n_components_sst):
    r.append(np.linalg.norm(df_cluster_sst[:,i] - ts[:,i]))
r_list.append(r)

# %%
plt.plot(r)

# %%
plt.plot(ts[:,36])

# %%
plt.plot(df_cluster_sst[:,36])
