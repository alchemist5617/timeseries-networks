# %%
import Pkg

# %%
Pkg.add("CausalityTools")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#  Installed ArrayInterface ────── v2.2.0
#  Installed SimpleDiffEq ──────── v1.0.2
#  Installed OffsetArrays ──────── v1.3.1
#  Installed CategoricalArrays ─── v0.7.7
#  Installed RecursiveArrayTools ─ v1.2.1
#  Installed UnPack ────────────── v1.0.2
#  Installed Distributions ─────── v0.21.9
#  Installed FillArrays ────────── v0.7.4
#  Installed DiffEqDiffTools ───── v1.6.0
#  Installed DiffEqBase ────────── v6.10.0
#  Installed DataFrames ────────── v0.20.2
#   Updating `~/.julia/environments/v1.1/Project.toml`
#   [5520caf5] + CausalityTools v0.7.0
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#   [621f4979] + AbstractFFTs v0.4.1
#   [7d9fca2a] + Arpack v0.3.2
#   [4fba245c] + ArrayInterface v2.2.0
#   [13072b0f] + AxisAlgorithms v1.0.0
#   [9e28174c] + BinDeps v1.0.2
# ...

# %%
Pkg.build("FFTW")
# Out:
#   Building Conda → `~/.julia/packages/Conda/x5ml4/deps/build.log`
#   Building FFTW ─→ `~/.julia/packages/FFTW/MJ7kl/deps/build.log`

# %%
Pkg.build("Arpack")
# Out:
#   Building Arpack → `~/.julia/packages/Arpack/zCmTA/deps/build.log`

# %%
Pkg.build("Rmath")
# Out:
#   Building Rmath → `~/.julia/packages/Rmath/BoBag/deps/build.log`

# %%
Pkg.build("PyCall")
# Out:
#   Building Conda ─→ `~/.julia/packages/Conda/x5ml4/deps/build.log`
#   Building PyCall → `~/.julia/packages/PyCall/BcTLp/deps/build.log`

# %%
Pkg.build("FFMPEG")
# Out:
#   Building FFMPEG → `~/.julia/packages/FFMPEG/guN1x/deps/build.log`
# ┌ Error: Error building `FFMPEG`:
# │ WARNING: replacing module Anon.
# │ WARNING: replacing module Anon.
# │ WARNING: replacing module Anon.
# │ WARNING: replacing module Anon.
# │ WARNING: replacing module Anon.
# │ WARNING: replacing module Anon.
# │ WARNING: replacing module Anon.
# │ WARNING: replacing module Anon.
# │ WARNING: replacing module Anon.
# │ [ Info: Downloading https://github.com/JuliaBinaryWrappers/Bzip2_jll.jl/releases/download/Bzip2-v1.0.6+1/Bzip2.v1.0.6.x86_64-linux-gnu.tar.gz to /home/mathsys2/.julia/packages/FFMPEG/guN1x/deps/usr/downloads/Bzip2.v1.0.6.x86_64-linux-gnu.tar.gz...
# │ [ Info: Downloading https://github.com/JuliaBinaryWrappers/Zlib_jll.jl/releases/download/Zlib-v1.2.11+7/Zlib.v1.2.11.x86_64-linux-gnu.tar.gz to /home/mathsys2/.julia/packages/FFMPEG/guN1x/deps/usr/downloads/Zlib.v1.2.11.x86_64-linux-gnu.tar.gz...
# ...

# %%
using CausalityTools
