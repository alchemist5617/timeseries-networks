# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# %%
from datetime import datetime
from packaging import version

import tensorflow as tf
from tensorflow import keras

import numpy as np

from tensorflow.keras import layers
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error
import csv
import scipy.stats as stats
from tensorboard.plugins.hparams import api as hp
import scipy.stats as stats
plt.rcParams["figure.figsize"] = (20,10)

import seaborn as sns
from Data import Data
from datetime import datetime
import feature_finder_keiko as ff
plt.rcParams["figure.figsize"] = (20,10)

# %%
step = 1
train_start = np.arange(1948,1977,step)
validation_end = np.arange(1982,2011,step)
test_start = np.arange(1983,2012,step)
test_end = np.arange(1987,2016,step)

n_components_sst = np.load("sst_number.npy")

# %%
tau = 12
f = 12
level = 99
extremes_treshold = -1

tau = 12

# %%
step = 1
train_start = np.arange(1951,1952,step)
validation_end = np.arange(2000,2001,step)
test_start = np.arange(2001,2002,step)
test_end = np.arange(2005,2006,step)

#n_components_sst = np.load("sst_number.npy")
n_components_sst = [69]


tau = 12
f = 12
level = 99
extremes_treshold = -1

# %%
test_start = np.arange(2011,2012,step)
test_end = np.arange(2015,2016,step)
data_sst_test = np.load("data_sst_test.npy")

# %%
ijz = -1
temporal_limits = {"time_min":datetime(train_start[ijz], 1, 1, 0, 0),"time_max":datetime(validation_end[ijz], 12, 1, 0, 0)}
original_count, count = ff.drought_timeseries("ET_gamma_18912015_12.npy",train_start[ijz],validation_end[ijz],extremes_treshold = extremes_treshold)

# %%
data_sst = np.load("data_sst.npy")
V = np.load("V.npy")
ts = np.load("ts.npy")
avg = np.load("avg.npy")
std = np.load("std.npy")
data_sst_test = np.load("data_sst_test.npy")
df_sst = pd.read_csv("df_sst.csv")

# %%
link  = np.load("../../whole_data_results/ET_orac/best_link_{}/pcmci_{}_{}_{}_{}_{}.npy".format(abs(extremes_treshold),f,train_start[ijz],validation_end[ijz],tau,n_components_sst[ijz]))

# %%
link  = np.load("../../whole_data_results/ET_orac/best_link_{}_1951/pcmci_{}_{}_{}_{}_{}.npy".format(abs(extremes_treshold),f,train_start[ijz],validation_end[ijz],tau,n_components_sst[ijz]))

# %%
temporal_limits_test = {"time_min":datetime(test_start[ijz], 1, 1, 0, 0),"time_max":datetime(test_end[ijz], 12, 1, 0, 0)}
#data_sst_test = ff.data_generator_avg_std('../../../nc/sst.mnmean.nc', "sst",temporal_limits_test, avg, std, 12, -9.96921e+36)
original_count_test, count_test = ff.drought_timeseries("ET_gamma_18912015_12.npy",test_start[ijz],test_end[ijz],extremes_treshold = extremes_treshold)

del df_sst["Unnamed: 0"]

# %%
original_count = np.array(original_count)/371
original_count_test = np.array(original_count_test)/371

# %%
start_lag = tau
end_lag = tau+11

df = pd.DataFrame({"drought": original_count})
lags = np.arange(start_lag,end_lag + 1)
df = df.assign(**{
'{} (t-{})'.format(col, t): df[col].shift(t)
for t in lags
for col in df
})
for k in range(len(link)):
    df[str(k)] = ff.time_series_maker_V(data_sst, V[:,link[k,0]-1])
    df[str(k)] = df[str(k)].shift(abs(link[k,1]))
df = df.dropna()

x_train = df.iloc[:,1:]
y_train = df.iloc[:,0]

# %%
start_lag = tau
end_lag = tau + 11

df_test = pd.DataFrame({"drought":original_count_test})
lags = np.arange(start_lag,end_lag + 1)
df_test = df_test.assign(**{
'{} (t-{})'.format(col, t): df_test[col].shift(t)
for t in lags
for col in df_test
})
for k in range(len(link)):
    df_sst["pc"] = V[:,link[k,0]-1]
    df_test[str(k)] = ff.time_series_maker(link[k,0]-1, df_sst, data_sst_test)
    #df_test[str(k)] = ff.time_series_maker_V(data_sst_test, V[:,link[k,0]-1])
    df_test[str(k)] = df_test[str(k)].shift(abs(link[k,1]))
df_test = df_test.dropna()

x_test = df_test.iloc[:,1:]
y_test = df_test.iloc[:,0]

# %%
n_components_sst = 98

link_caus = np.load("./link_rotated_station/best_link_1976_2010_{}.npy".format(tau))
link_corr = np.load("./link_rotated_station/best_link_corr_1976_2010_{}.npy".format(tau))


train_start = 1976
validation_end = 2010

temporal_limits = {"time_min":datetime(train_start, 1, 1, 0, 0),"time_max":datetime(validation_end, 12, 1, 0, 0)}
original_count, count = ff.drought_timeseries("ET_gamma_18912015.npy",train_start,validation_end)
#data_sst, ts, V, df_sst, avg, std = ff.PCA_computer_rotated(file_name, "sst",temporal_limits, n_components_sst, -9.96921e+36)

data_sst = np.load("data_sst.npy")
V = np.load("V.npy")
ts = np.load("ts.npy")
avg = np.load("avg.npy")
std = np.load("std.npy")
data_sst_test = np.load("data_sst_test.npy")

df_sst = pd.read_csv("df_sst.csv")

test_start = 2011
test_end = 2015

temporal_limits_test = {"time_min":datetime(test_start, 1, 1, 0, 0),"time_max":datetime(test_end, 12, 1, 0, 0)}
#data_sst_test = ff.data_generator_avg_std('../../../nc/sst.mnmean.nc', "sst",temporal_limits_test, avg, std, 12, -9.96921e+36)
original_count_test, count_test = ff.drought_timeseries("../npy_files/ET_gamma_18912015.npy",test_start,test_end)

del df_sst["Unnamed: 0"]

# %%
#Hybrid

for i in range(len(link_corr)):
    if not np.array(link_corr == list(link_corr[i])).all(axis=1).all():
        link_caus = np.concatenate((link_caus, np.reshape(link_corr[i,:],(1,2))))
link_hybrid = link_caus
link_caus = np.load("./link_rotated_station/best_link_1976_2010_{}.npy".format(tau))

l, b, m = ff.forward_feature_V(count, data_sst, link_hybrid, V, tau)

link = l

start_lag = tau
end_lag = tau + 12

df_test = pd.DataFrame({"drought":original_count_test})
lags = np.arange(start_lag,end_lag + 1)
df_test = df_test.assign(**{
'{} (t-{})'.format(col, t): df_test[col].shift(t)
for t in lags
for col in df_test
})
for k in range(len(link)):
    df_sst["pc"] = V[:,link[k,0]-1]
    df_test[str(k)] = ff.time_series_maker(link[k,0]-1, df_sst, data_sst_test)
    df_test[str(k)] = df_test[str(k)].shift(abs(link[k,1]))
df_test = df_test.dropna()

x_test = df_test.iloc[:,1:]
y_test = df_test.iloc[:,0]

# %%
link = l

start_lag = tau
end_lag = tau+12

df = pd.DataFrame({"drought": original_count})
lags = np.arange(start_lag,end_lag + 1)
df = df.assign(**{
'{} (t-{})'.format(col, t): df[col].shift(t)
for t in lags
for col in df
})
for k in range(len(link)):
    df[str(k)] = ff.time_series_maker_V(data_sst, V[:,link[k,0]-1])
    df[str(k)] = df[str(k)].shift(abs(link[k,1]))
df = df.dropna()

x_train = df.iloc[:,1:]
y_train = df.iloc[:,0]

start_lag = tau
end_lag = tau + 12

df_test = pd.DataFrame({"drought":original_count_test})
lags = np.arange(start_lag,end_lag + 1)
df_test = df_test.assign(**{
'{} (t-{})'.format(col, t): df_test[col].shift(t)
for t in lags
for col in df_test
})
for k in range(len(link)):
    df_sst["pc"] = V[:,link[k,0]-1]
    df_test[str(k)] = ff.time_series_maker(link[k,0]-1, df_sst, data_sst_test)
    df_test[str(k)] = df_test[str(k)].shift(abs(link[k,1]))
df_test = df_test.dropna()

x_test = df_test.iloc[:,1:]
y_test = df_test.iloc[:,0]

# %%
layers.Dense(16, kernel_regularizer=tf.keras.regularizers.l2(0.01), activation=tf.nn.relu),
layers.Dropout(0.1),
layers.Dense(16, kernel_regularizer=tf.keras.regularizers.l2(0.01), activation=tf.nn.relu),
layers.Dropout(0.1),

# %%
logdir = "logs/scalars/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

#model = tf.keras.Sequential([
#tf.keras.layers.InputLayer(input_shape = x_train.shape[1]),
#layers.Dense(16, kernel_regularizer=tf.keras.regularizers.l2(0.01), activation=tf.nn.relu),
#layers.Dropout(0.1),
#layers.Dense(16, kernel_regularizer=tf.keras.regularizers.l2(0.01), activation=tf.nn.relu),
#layers.Dropout(0.1),
#layers.Dense(16, kernel_regularizer=tf.keras.regularizers.l2(0.01), activation=tf.nn.relu),
#layers.Dense(1)
#])

model = tf.keras.Sequential([
tf.keras.layers.InputLayer(input_shape = x_train.shape[1]),
layers.Dense(16, kernel_regularizer=tf.keras.regularizers.l2(0.01), activation=tf.nn.relu),
layers.Dropout(0.1),
layers.Dense(8, kernel_regularizer=tf.keras.regularizers.l2(0.01), activation=tf.nn.relu),
layers.Dense(1)
])



#model = keras.models.Sequential([
#    keras.layers.Dense(16, input_dim=1),
#    keras.layers.Dense(1),
#])

model.compile(
    loss='mean_squared_error', # keras.losses.mean_squared_error
    optimizer=keras.optimizers.RMSprop(lr=1e-06),
    metrics=['RootMeanSquaredError']
)

print("Training ... With default parameters, this takes less than 10 seconds.")
training_history = model.fit(
    x_train, # input
    y_train, # output
    verbose=True, # Suppress chatty output; use Tensorboard instead
    epochs=5000,
    validation_data=(x_test, y_test),
    callbacks=[tensorboard_callback],
)

print("Average test loss: ", np.average(training_history.history['loss']))
# Out:
# Training ... With default parameters, this takes less than 10 seconds.
# Train on 397 samples, validate on 37 samples
# Epoch 1/5000
# 397/397 [==============================] - 0s 1ms/sample - loss: 4133.1565 - RootMeanSquaredError: 64.2874 - val_loss: 636.2347 - val_RootMeanSquaredError: 25.2180
# Epoch 2/5000
# 397/397 [==============================] - 0s 73us/sample - loss: 4182.7131 - RootMeanSquaredError: 64.6717 - val_loss: 636.2792 - val_RootMeanSquaredError: 25.2189
# Epoch 3/5000
# 397/397 [==============================] - 0s 72us/sample - loss: 4163.2461 - RootMeanSquaredError: 64.5210 - val_loss: 636.3250 - val_RootMeanSquaredError: 25.2198
# Epoch 4/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4167.2343 - RootMeanSquaredError: 64.5519 - val_loss: 636.3700 - val_RootMeanSquaredError: 25.2207
# Epoch 5/5000
# 397/397 [==============================] - 0s 66us/sample - loss: 4107.6032 - RootMeanSquaredError: 64.0883 - val_loss: 636.4264 - val_RootMeanSquaredError: 25.2218
# Epoch 6/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 4264.2545 - RootMeanSquaredError: 65.2990 - val_loss: 636.4726 - val_RootMeanSquaredError: 25.2227
# Epoch 7/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 4084.1383 - RootMeanSquaredError: 63.9050 - val_loss: 636.5204 - val_RootMeanSquaredError: 25.2236
# Epoch 8/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 4159.5368 - RootMeanSquaredError: 64.4922 - val_loss: 636.5666 - val_RootMeanSquaredError: 25.2246
# Epoch 9/5000
# 397/397 [==============================] - 0s 70us/sample - loss: 4050.8914 - RootMeanSquaredError: 63.6443 - val_loss: 636.6090 - val_RootMeanSquaredError: 25.2254
# Epoch 10/5000
# 397/397 [==============================] - 0s 70us/sample - loss: 4143.1824 - RootMeanSquaredError: 64.3653 - val_loss: 636.6647 - val_RootMeanSquaredError: 25.2265
# Epoch 11/5000
# 397/397 [==============================] - 0s 68us/sample - loss: 4067.2459 - RootMeanSquaredError: 63.7727 - val_loss: 636.7157 - val_RootMeanSquaredError: 25.2275
# Epoch 12/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4108.1572 - RootMeanSquaredError: 64.0927 - val_loss: 636.7622 - val_RootMeanSquaredError: 25.2284
# Epoch 13/5000
# 397/397 [==============================] - 0s 58us/sample - loss: 4167.5090 - RootMeanSquaredError: 64.5540 - val_loss: 636.7988 - val_RootMeanSquaredError: 25.2292
# Epoch 14/5000
# 397/397 [==============================] - 0s 69us/sample - loss: 4146.9205 - RootMeanSquaredError: 64.3944 - val_loss: 636.8463 - val_RootMeanSquaredError: 25.2301
# Epoch 15/5000
# 397/397 [==============================] - 0s 66us/sample - loss: 4196.0800 - RootMeanSquaredError: 64.7749 - val_loss: 636.8926 - val_RootMeanSquaredError: 25.2310
# Epoch 16/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 4192.3771 - RootMeanSquaredError: 64.7463 - val_loss: 636.9401 - val_RootMeanSquaredError: 25.2320
# Epoch 17/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4120.4215 - RootMeanSquaredError: 64.1883 - val_loss: 636.9772 - val_RootMeanSquaredError: 25.2327
# Epoch 18/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 4219.7025 - RootMeanSquaredError: 64.9570 - val_loss: 637.0204 - val_RootMeanSquaredError: 25.2336
# Epoch 19/5000
# 397/397 [==============================] - 0s 69us/sample - loss: 4163.9614 - RootMeanSquaredError: 64.5265 - val_loss: 637.0619 - val_RootMeanSquaredError: 25.2344
# Epoch 20/5000
# 397/397 [==============================] - 0s 70us/sample - loss: 4152.7341 - RootMeanSquaredError: 64.4395 - val_loss: 637.0981 - val_RootMeanSquaredError: 25.2351
# Epoch 21/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4162.9446 - RootMeanSquaredError: 64.5187 - val_loss: 637.1451 - val_RootMeanSquaredError: 25.2360
# Epoch 22/5000
# 397/397 [==============================] - 0s 73us/sample - loss: 4083.9105 - RootMeanSquaredError: 63.9032 - val_loss: 637.1873 - val_RootMeanSquaredError: 25.2369
# Epoch 23/5000
# 397/397 [==============================] - 0s 70us/sample - loss: 4155.6925 - RootMeanSquaredError: 64.4624 - val_loss: 637.2287 - val_RootMeanSquaredError: 25.2377
# Epoch 24/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4113.7490 - RootMeanSquaredError: 64.1363 - val_loss: 637.2726 - val_RootMeanSquaredError: 25.2386
# Epoch 25/5000
# 397/397 [==============================] - 0s 68us/sample - loss: 4160.0722 - RootMeanSquaredError: 64.4964 - val_loss: 637.3140 - val_RootMeanSquaredError: 25.2394
# Epoch 26/5000
# 397/397 [==============================] - 0s 70us/sample - loss: 4201.3221 - RootMeanSquaredError: 64.8154 - val_loss: 637.3639 - val_RootMeanSquaredError: 25.2404
# Epoch 27/5000
# 397/397 [==============================] - 0s 66us/sample - loss: 4144.1194 - RootMeanSquaredError: 64.3726 - val_loss: 637.3993 - val_RootMeanSquaredError: 25.2411
# Epoch 28/5000
# 397/397 [==============================] - 0s 68us/sample - loss: 4261.5944 - RootMeanSquaredError: 65.2787 - val_loss: 637.4402 - val_RootMeanSquaredError: 25.2419
# Epoch 29/5000
# 397/397 [==============================] - 0s 74us/sample - loss: 4193.0413 - RootMeanSquaredError: 64.7515 - val_loss: 637.4880 - val_RootMeanSquaredError: 25.2428
# Epoch 30/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 4150.1256 - RootMeanSquaredError: 64.4192 - val_loss: 637.5390 - val_RootMeanSquaredError: 25.2438
# Epoch 31/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4046.7148 - RootMeanSquaredError: 63.6115 - val_loss: 637.5830 - val_RootMeanSquaredError: 25.2447
# Epoch 32/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4193.8348 - RootMeanSquaredError: 64.7576 - val_loss: 637.6197 - val_RootMeanSquaredError: 25.2454
# Epoch 33/5000
# 397/397 [==============================] - 0s 76us/sample - loss: 4133.3076 - RootMeanSquaredError: 64.2886 - val_loss: 637.6588 - val_RootMeanSquaredError: 25.2462
# Epoch 34/5000
# 397/397 [==============================] - 0s 70us/sample - loss: 4181.8435 - RootMeanSquaredError: 64.6649 - val_loss: 637.6968 - val_RootMeanSquaredError: 25.2470
# Epoch 35/5000
# 397/397 [==============================] - 0s 95us/sample - loss: 4249.8951 - RootMeanSquaredError: 65.1890 - val_loss: 637.7391 - val_RootMeanSquaredError: 25.2478
# Epoch 36/5000
# 397/397 [==============================] - 0s 72us/sample - loss: 4175.8049 - RootMeanSquaredError: 64.6182 - val_loss: 637.7797 - val_RootMeanSquaredError: 25.2486
# Epoch 37/5000
# 397/397 [==============================] - 0s 70us/sample - loss: 4100.1058 - RootMeanSquaredError: 64.0298 - val_loss: 637.8308 - val_RootMeanSquaredError: 25.2496
# Epoch 38/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4229.5645 - RootMeanSquaredError: 65.0329 - val_loss: 637.8703 - val_RootMeanSquaredError: 25.2504
# Epoch 39/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4233.1946 - RootMeanSquaredError: 65.0608 - val_loss: 637.9166 - val_RootMeanSquaredError: 25.2513
# Epoch 40/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4193.7209 - RootMeanSquaredError: 64.7567 - val_loss: 637.9646 - val_RootMeanSquaredError: 25.2523
# Epoch 41/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4140.4970 - RootMeanSquaredError: 64.3445 - val_loss: 638.0111 - val_RootMeanSquaredError: 25.2532
# Epoch 42/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4239.7983 - RootMeanSquaredError: 65.1115 - val_loss: 638.0535 - val_RootMeanSquaredError: 25.2540
# Epoch 43/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4148.9969 - RootMeanSquaredError: 64.4105 - val_loss: 638.1028 - val_RootMeanSquaredError: 25.2550
# Epoch 44/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4123.3319 - RootMeanSquaredError: 64.2109 - val_loss: 638.1512 - val_RootMeanSquaredError: 25.2560
# Epoch 45/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4205.9894 - RootMeanSquaredError: 64.8514 - val_loss: 638.1985 - val_RootMeanSquaredError: 25.2569
# Epoch 46/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4179.7877 - RootMeanSquaredError: 64.6490 - val_loss: 638.2349 - val_RootMeanSquaredError: 25.2576
# Epoch 47/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 4091.4039 - RootMeanSquaredError: 63.9618 - val_loss: 638.2830 - val_RootMeanSquaredError: 25.2586
# Epoch 48/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4019.0341 - RootMeanSquaredError: 63.3936 - val_loss: 638.3333 - val_RootMeanSquaredError: 25.2596
# Epoch 49/5000
# 397/397 [==============================] - 0s 68us/sample - loss: 4148.8017 - RootMeanSquaredError: 64.4090 - val_loss: 638.3760 - val_RootMeanSquaredError: 25.2604
# Epoch 50/5000
# 397/397 [==============================] - 0s 66us/sample - loss: 4192.0355 - RootMeanSquaredError: 64.7437 - val_loss: 638.4268 - val_RootMeanSquaredError: 25.2614
# Epoch 51/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4115.5805 - RootMeanSquaredError: 64.1506 - val_loss: 638.4769 - val_RootMeanSquaredError: 25.2624
# Epoch 52/5000
# 397/397 [==============================] - 0s 68us/sample - loss: 4263.0133 - RootMeanSquaredError: 65.2896 - val_loss: 638.5212 - val_RootMeanSquaredError: 25.2633
# Epoch 53/5000
# 397/397 [==============================] - 0s 68us/sample - loss: 4109.7851 - RootMeanSquaredError: 64.1054 - val_loss: 638.5775 - val_RootMeanSquaredError: 25.2644
# Epoch 54/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4185.8011 - RootMeanSquaredError: 64.6955 - val_loss: 638.6211 - val_RootMeanSquaredError: 25.2653
# Epoch 55/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 4182.3434 - RootMeanSquaredError: 64.6688 - val_loss: 638.6755 - val_RootMeanSquaredError: 25.2663
# Epoch 56/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4194.1193 - RootMeanSquaredError: 64.7598 - val_loss: 638.7183 - val_RootMeanSquaredError: 25.2672
# Epoch 57/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4155.4546 - RootMeanSquaredError: 64.4606 - val_loss: 638.7632 - val_RootMeanSquaredError: 25.2681
# Epoch 58/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4073.4885 - RootMeanSquaredError: 63.8216 - val_loss: 638.8099 - val_RootMeanSquaredError: 25.2690
# Epoch 59/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4195.7584 - RootMeanSquaredError: 64.7725 - val_loss: 638.8565 - val_RootMeanSquaredError: 25.2699
# Epoch 60/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4100.3158 - RootMeanSquaredError: 64.0315 - val_loss: 638.9090 - val_RootMeanSquaredError: 25.2709
# Epoch 61/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4081.0701 - RootMeanSquaredError: 63.8810 - val_loss: 638.9595 - val_RootMeanSquaredError: 25.2719
# Epoch 62/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4130.6144 - RootMeanSquaredError: 64.2676 - val_loss: 639.0073 - val_RootMeanSquaredError: 25.2729
# Epoch 63/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4091.1888 - RootMeanSquaredError: 63.9602 - val_loss: 639.0548 - val_RootMeanSquaredError: 25.2738
# Epoch 64/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4004.6056 - RootMeanSquaredError: 63.2797 - val_loss: 639.1021 - val_RootMeanSquaredError: 25.2748
# Epoch 65/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4199.9172 - RootMeanSquaredError: 64.8046 - val_loss: 639.1410 - val_RootMeanSquaredError: 25.2755
# Epoch 66/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 4112.6268 - RootMeanSquaredError: 64.1275 - val_loss: 639.1868 - val_RootMeanSquaredError: 25.2764
# Epoch 67/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4197.0174 - RootMeanSquaredError: 64.7822 - val_loss: 639.2416 - val_RootMeanSquaredError: 25.2775
# Epoch 68/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4165.7233 - RootMeanSquaredError: 64.5402 - val_loss: 639.2918 - val_RootMeanSquaredError: 25.2785
# Epoch 69/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4118.0201 - RootMeanSquaredError: 64.1696 - val_loss: 639.3449 - val_RootMeanSquaredError: 25.2796
# Epoch 70/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4153.1587 - RootMeanSquaredError: 64.4428 - val_loss: 639.3925 - val_RootMeanSquaredError: 25.2805
# Epoch 71/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4118.6727 - RootMeanSquaredError: 64.1746 - val_loss: 639.4481 - val_RootMeanSquaredError: 25.2816
# Epoch 72/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4130.2177 - RootMeanSquaredError: 64.2645 - val_loss: 639.4994 - val_RootMeanSquaredError: 25.2826
# Epoch 73/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4113.2304 - RootMeanSquaredError: 64.1322 - val_loss: 639.5434 - val_RootMeanSquaredError: 25.2835
# Epoch 74/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4154.8612 - RootMeanSquaredError: 64.4560 - val_loss: 639.5912 - val_RootMeanSquaredError: 25.2844
# Epoch 75/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4213.4463 - RootMeanSquaredError: 64.9088 - val_loss: 639.6303 - val_RootMeanSquaredError: 25.2852
# Epoch 76/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4030.1679 - RootMeanSquaredError: 63.4813 - val_loss: 639.6857 - val_RootMeanSquaredError: 25.2863
# Epoch 77/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4190.4351 - RootMeanSquaredError: 64.7313 - val_loss: 639.7331 - val_RootMeanSquaredError: 25.2872
# Epoch 78/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4085.7553 - RootMeanSquaredError: 63.9177 - val_loss: 639.7886 - val_RootMeanSquaredError: 25.2883
# Epoch 79/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4139.8918 - RootMeanSquaredError: 64.3398 - val_loss: 639.8326 - val_RootMeanSquaredError: 25.2892
# Epoch 80/5000
# 397/397 [==============================] - 0s 66us/sample - loss: 4118.7213 - RootMeanSquaredError: 64.1750 - val_loss: 639.8896 - val_RootMeanSquaredError: 25.2903
# Epoch 81/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4078.9567 - RootMeanSquaredError: 63.8645 - val_loss: 639.9308 - val_RootMeanSquaredError: 25.2912
# Epoch 82/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4111.3670 - RootMeanSquaredError: 64.1177 - val_loss: 639.9768 - val_RootMeanSquaredError: 25.2921
# Epoch 83/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4111.8146 - RootMeanSquaredError: 64.1212 - val_loss: 640.0347 - val_RootMeanSquaredError: 25.2932
# Epoch 84/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4045.3123 - RootMeanSquaredError: 63.6005 - val_loss: 640.0851 - val_RootMeanSquaredError: 25.2942
# Epoch 85/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4026.8096 - RootMeanSquaredError: 63.4549 - val_loss: 640.1445 - val_RootMeanSquaredError: 25.2954
# Epoch 86/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4187.0267 - RootMeanSquaredError: 64.7050 - val_loss: 640.1889 - val_RootMeanSquaredError: 25.2963
# Epoch 87/5000
# 397/397 [==============================] - 0s 69us/sample - loss: 4113.9395 - RootMeanSquaredError: 64.1378 - val_loss: 640.2393 - val_RootMeanSquaredError: 25.2973
# Epoch 88/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4153.8081 - RootMeanSquaredError: 64.4478 - val_loss: 640.2858 - val_RootMeanSquaredError: 25.2982
# Epoch 89/5000
# 397/397 [==============================] - 0s 66us/sample - loss: 4069.5076 - RootMeanSquaredError: 63.7904 - val_loss: 640.3410 - val_RootMeanSquaredError: 25.2993
# Epoch 90/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4110.9511 - RootMeanSquaredError: 64.1144 - val_loss: 640.3904 - val_RootMeanSquaredError: 25.3002
# Epoch 91/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4082.1923 - RootMeanSquaredError: 63.8898 - val_loss: 640.4384 - val_RootMeanSquaredError: 25.3012
# Epoch 92/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 4102.5994 - RootMeanSquaredError: 64.0493 - val_loss: 640.4828 - val_RootMeanSquaredError: 25.3021
# Epoch 93/5000
# 397/397 [==============================] - 0s 66us/sample - loss: 4175.3054 - RootMeanSquaredError: 64.6144 - val_loss: 640.5291 - val_RootMeanSquaredError: 25.3030
# Epoch 94/5000
# 397/397 [==============================] - 0s 72us/sample - loss: 4183.7680 - RootMeanSquaredError: 64.6798 - val_loss: 640.5803 - val_RootMeanSquaredError: 25.3040
# Epoch 95/5000
# 397/397 [==============================] - 0s 98us/sample - loss: 4088.7246 - RootMeanSquaredError: 63.9409 - val_loss: 640.6309 - val_RootMeanSquaredError: 25.3050
# Epoch 96/5000
# 397/397 [==============================] - 0s 100us/sample - loss: 4142.9955 - RootMeanSquaredError: 64.3639 - val_loss: 640.6867 - val_RootMeanSquaredError: 25.3061
# Epoch 97/5000
# 397/397 [==============================] - 0s 70us/sample - loss: 4196.2722 - RootMeanSquaredError: 64.7764 - val_loss: 640.7440 - val_RootMeanSquaredError: 25.3072
# Epoch 98/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4069.0610 - RootMeanSquaredError: 63.7869 - val_loss: 640.8024 - val_RootMeanSquaredError: 25.3084
# Epoch 99/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4205.0716 - RootMeanSquaredError: 64.8443 - val_loss: 640.8459 - val_RootMeanSquaredError: 25.3092
# Epoch 100/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4184.4970 - RootMeanSquaredError: 64.6855 - val_loss: 640.8976 - val_RootMeanSquaredError: 25.3103
# Epoch 101/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4115.0479 - RootMeanSquaredError: 64.1464 - val_loss: 640.9429 - val_RootMeanSquaredError: 25.3112
# Epoch 102/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4072.2970 - RootMeanSquaredError: 63.8123 - val_loss: 641.0089 - val_RootMeanSquaredError: 25.3125
# Epoch 103/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4095.6211 - RootMeanSquaredError: 63.9948 - val_loss: 641.0586 - val_RootMeanSquaredError: 25.3134
# Epoch 104/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 3985.9619 - RootMeanSquaredError: 63.1322 - val_loss: 641.1121 - val_RootMeanSquaredError: 25.3145
# Epoch 105/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4047.3756 - RootMeanSquaredError: 63.6167 - val_loss: 641.1731 - val_RootMeanSquaredError: 25.3157
# Epoch 106/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4087.7316 - RootMeanSquaredError: 63.9331 - val_loss: 641.2414 - val_RootMeanSquaredError: 25.3171
# Epoch 107/5000
# 397/397 [==============================] - 0s 70us/sample - loss: 4135.8635 - RootMeanSquaredError: 64.3084 - val_loss: 641.3012 - val_RootMeanSquaredError: 25.3182
# Epoch 108/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4116.3230 - RootMeanSquaredError: 64.1563 - val_loss: 641.3714 - val_RootMeanSquaredError: 25.3196
# Epoch 109/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4152.9562 - RootMeanSquaredError: 64.4412 - val_loss: 641.4445 - val_RootMeanSquaredError: 25.3211
# Epoch 110/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4065.7251 - RootMeanSquaredError: 63.7608 - val_loss: 641.5076 - val_RootMeanSquaredError: 25.3223
# Epoch 111/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4139.5777 - RootMeanSquaredError: 64.3373 - val_loss: 641.5859 - val_RootMeanSquaredError: 25.3239
# Epoch 112/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4147.2844 - RootMeanSquaredError: 64.3972 - val_loss: 641.6360 - val_RootMeanSquaredError: 25.3248
# Epoch 113/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4140.9407 - RootMeanSquaredError: 64.3479 - val_loss: 641.7068 - val_RootMeanSquaredError: 25.3262
# Epoch 114/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4051.1636 - RootMeanSquaredError: 63.6465 - val_loss: 641.7648 - val_RootMeanSquaredError: 25.3274
# Epoch 115/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4103.6270 - RootMeanSquaredError: 64.0573 - val_loss: 641.8264 - val_RootMeanSquaredError: 25.3286
# Epoch 116/5000
# 397/397 [==============================] - 0s 66us/sample - loss: 4152.2055 - RootMeanSquaredError: 64.4354 - val_loss: 641.8893 - val_RootMeanSquaredError: 25.3298
# Epoch 117/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4112.1309 - RootMeanSquaredError: 64.1236 - val_loss: 641.9558 - val_RootMeanSquaredError: 25.3312
# Epoch 118/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4137.0125 - RootMeanSquaredError: 64.3174 - val_loss: 642.0149 - val_RootMeanSquaredError: 25.3323
# Epoch 119/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4111.9492 - RootMeanSquaredError: 64.1222 - val_loss: 642.0819 - val_RootMeanSquaredError: 25.3336
# Epoch 120/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4109.5086 - RootMeanSquaredError: 64.1032 - val_loss: 642.1462 - val_RootMeanSquaredError: 25.3349
# Epoch 121/5000
# 397/397 [==============================] - ETA: 0s - loss: 3079.5911 - RootMeanSquaredError: 55.49 - 0s 62us/sample - loss: 4111.9093 - RootMeanSquaredError: 64.1219 - val_loss: 642.2021 - val_RootMeanSquaredError: 25.3360
# Epoch 122/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4096.9140 - RootMeanSquaredError: 64.0049 - val_loss: 642.2636 - val_RootMeanSquaredError: 25.3372
# Epoch 123/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4164.1036 - RootMeanSquaredError: 64.5276 - val_loss: 642.3267 - val_RootMeanSquaredError: 25.3385
# Epoch 124/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4069.8974 - RootMeanSquaredError: 63.7935 - val_loss: 642.3965 - val_RootMeanSquaredError: 25.3399
# Epoch 125/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4001.8642 - RootMeanSquaredError: 63.2580 - val_loss: 642.4705 - val_RootMeanSquaredError: 25.3413
# Epoch 126/5000
# 397/397 [==============================] - 0s 66us/sample - loss: 4062.8432 - RootMeanSquaredError: 63.7382 - val_loss: 642.5382 - val_RootMeanSquaredError: 25.3426
# Epoch 127/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 3978.0982 - RootMeanSquaredError: 63.0699 - val_loss: 642.5945 - val_RootMeanSquaredError: 25.3438
# Epoch 128/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4102.2769 - RootMeanSquaredError: 64.0468 - val_loss: 642.6548 - val_RootMeanSquaredError: 25.3449
# Epoch 129/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4069.0167 - RootMeanSquaredError: 63.7866 - val_loss: 642.7239 - val_RootMeanSquaredError: 25.3463
# Epoch 130/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4098.4226 - RootMeanSquaredError: 64.0167 - val_loss: 642.7965 - val_RootMeanSquaredError: 25.3477
# Epoch 131/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4090.2705 - RootMeanSquaredError: 63.9530 - val_loss: 642.8630 - val_RootMeanSquaredError: 25.3491
# Epoch 132/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4107.0077 - RootMeanSquaredError: 64.0837 - val_loss: 642.9231 - val_RootMeanSquaredError: 25.3502
# Epoch 133/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4108.2203 - RootMeanSquaredError: 64.0932 - val_loss: 642.9826 - val_RootMeanSquaredError: 25.3514
# Epoch 134/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4016.9816 - RootMeanSquaredError: 63.3774 - val_loss: 643.0570 - val_RootMeanSquaredError: 25.3529
# Epoch 135/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4016.3473 - RootMeanSquaredError: 63.3724 - val_loss: 643.1199 - val_RootMeanSquaredError: 25.3541
# Epoch 136/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4034.5654 - RootMeanSquaredError: 63.5160 - val_loss: 643.1831 - val_RootMeanSquaredError: 25.3554
# Epoch 137/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4121.3447 - RootMeanSquaredError: 64.1954 - val_loss: 643.2458 - val_RootMeanSquaredError: 25.3566
# Epoch 138/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4147.2223 - RootMeanSquaredError: 64.3967 - val_loss: 643.3117 - val_RootMeanSquaredError: 25.3579
# Epoch 139/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4091.3163 - RootMeanSquaredError: 63.9611 - val_loss: 643.3750 - val_RootMeanSquaredError: 25.3592
# Epoch 140/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4112.3128 - RootMeanSquaredError: 64.1251 - val_loss: 643.4417 - val_RootMeanSquaredError: 25.3605
# Epoch 141/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 3983.1282 - RootMeanSquaredError: 63.1097 - val_loss: 643.5180 - val_RootMeanSquaredError: 25.3620
# Epoch 142/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4054.7967 - RootMeanSquaredError: 63.6750 - val_loss: 643.5966 - val_RootMeanSquaredError: 25.3635
# Epoch 143/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4147.1600 - RootMeanSquaredError: 64.3962 - val_loss: 643.6598 - val_RootMeanSquaredError: 25.3648
# Epoch 144/5000
# 397/397 [==============================] - 0s 58us/sample - loss: 4192.8902 - RootMeanSquaredError: 64.7503 - val_loss: 643.7197 - val_RootMeanSquaredError: 25.3659
# Epoch 145/5000
# 397/397 [==============================] - ETA: 0s - loss: 3269.2668 - RootMeanSquaredError: 57.17 - 0s 63us/sample - loss: 4117.6583 - RootMeanSquaredError: 64.1667 - val_loss: 643.7741 - val_RootMeanSquaredError: 25.3670
# Epoch 146/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4054.3314 - RootMeanSquaredError: 63.6714 - val_loss: 643.8433 - val_RootMeanSquaredError: 25.3684
# Epoch 147/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4163.0241 - RootMeanSquaredError: 64.5193 - val_loss: 643.9163 - val_RootMeanSquaredError: 25.3698
# Epoch 148/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4053.0112 - RootMeanSquaredError: 63.6610 - val_loss: 643.9744 - val_RootMeanSquaredError: 25.3710
# Epoch 149/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4221.9701 - RootMeanSquaredError: 64.9745 - val_loss: 644.0474 - val_RootMeanSquaredError: 25.3724
# Epoch 150/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4133.4150 - RootMeanSquaredError: 64.2894 - val_loss: 644.1195 - val_RootMeanSquaredError: 25.3738
# Epoch 151/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4082.3846 - RootMeanSquaredError: 63.8913 - val_loss: 644.1925 - val_RootMeanSquaredError: 25.3753
# Epoch 152/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4076.7502 - RootMeanSquaredError: 63.8472 - val_loss: 644.2641 - val_RootMeanSquaredError: 25.3767
# Epoch 153/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4012.0585 - RootMeanSquaredError: 63.3385 - val_loss: 644.3292 - val_RootMeanSquaredError: 25.3780
# Epoch 154/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4023.0180 - RootMeanSquaredError: 63.4250 - val_loss: 644.4041 - val_RootMeanSquaredError: 25.3794
# Epoch 155/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4135.3130 - RootMeanSquaredError: 64.3042 - val_loss: 644.4751 - val_RootMeanSquaredError: 25.3808
# Epoch 156/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4011.9614 - RootMeanSquaredError: 63.3378 - val_loss: 644.5458 - val_RootMeanSquaredError: 25.3822
# Epoch 157/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4092.9013 - RootMeanSquaredError: 63.9735 - val_loss: 644.6320 - val_RootMeanSquaredError: 25.3839
# Epoch 158/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4022.8060 - RootMeanSquaredError: 63.4233 - val_loss: 644.6906 - val_RootMeanSquaredError: 25.3851
# Epoch 159/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 4074.9455 - RootMeanSquaredError: 63.8330 - val_loss: 644.7585 - val_RootMeanSquaredError: 25.3864
# Epoch 160/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4044.0718 - RootMeanSquaredError: 63.5907 - val_loss: 644.8352 - val_RootMeanSquaredError: 25.3879
# Epoch 161/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4125.9615 - RootMeanSquaredError: 64.2314 - val_loss: 644.9087 - val_RootMeanSquaredError: 25.3894
# Epoch 162/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4174.3136 - RootMeanSquaredError: 64.6067 - val_loss: 644.9699 - val_RootMeanSquaredError: 25.3906
# Epoch 163/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4212.5307 - RootMeanSquaredError: 64.9018 - val_loss: 645.0487 - val_RootMeanSquaredError: 25.3921
# Epoch 164/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 3956.6693 - RootMeanSquaredError: 62.8998 - val_loss: 645.1345 - val_RootMeanSquaredError: 25.3938
# Epoch 165/5000
# 397/397 [==============================] - 0s 70us/sample - loss: 4037.8145 - RootMeanSquaredError: 63.5415 - val_loss: 645.2019 - val_RootMeanSquaredError: 25.3951
# Epoch 166/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4002.6773 - RootMeanSquaredError: 63.2644 - val_loss: 645.2730 - val_RootMeanSquaredError: 25.3965
# Epoch 167/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4091.7516 - RootMeanSquaredError: 63.9645 - val_loss: 645.3519 - val_RootMeanSquaredError: 25.3981
# Epoch 168/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 3971.0781 - RootMeanSquaredError: 63.0142 - val_loss: 645.4232 - val_RootMeanSquaredError: 25.3995
# Epoch 169/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4074.9507 - RootMeanSquaredError: 63.8331 - val_loss: 645.5004 - val_RootMeanSquaredError: 25.4010
# Epoch 170/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4070.0331 - RootMeanSquaredError: 63.7946 - val_loss: 645.5624 - val_RootMeanSquaredError: 25.4022
# Epoch 171/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4079.2970 - RootMeanSquaredError: 63.8671 - val_loss: 645.6480 - val_RootMeanSquaredError: 25.4039
# Epoch 172/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4104.5038 - RootMeanSquaredError: 64.0641 - val_loss: 645.7215 - val_RootMeanSquaredError: 25.4054
# Epoch 173/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4122.9522 - RootMeanSquaredError: 64.2080 - val_loss: 645.7902 - val_RootMeanSquaredError: 25.4067
# Epoch 174/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4146.0165 - RootMeanSquaredError: 64.3873 - val_loss: 645.8651 - val_RootMeanSquaredError: 25.4082
# Epoch 175/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4022.6559 - RootMeanSquaredError: 63.4221 - val_loss: 645.9365 - val_RootMeanSquaredError: 25.4096
# Epoch 176/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4032.7552 - RootMeanSquaredError: 63.5017 - val_loss: 646.0174 - val_RootMeanSquaredError: 25.4112
# Epoch 177/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 3993.6565 - RootMeanSquaredError: 63.1931 - val_loss: 646.0912 - val_RootMeanSquaredError: 25.4127
# Epoch 178/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4213.9149 - RootMeanSquaredError: 64.9125 - val_loss: 646.1607 - val_RootMeanSquaredError: 25.4140
# Epoch 179/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4085.0156 - RootMeanSquaredError: 63.9119 - val_loss: 646.2373 - val_RootMeanSquaredError: 25.4155
# Epoch 180/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4093.9211 - RootMeanSquaredError: 63.9815 - val_loss: 646.3063 - val_RootMeanSquaredError: 25.4169
# Epoch 181/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4059.9765 - RootMeanSquaredError: 63.7157 - val_loss: 646.3814 - val_RootMeanSquaredError: 25.4184
# Epoch 182/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4130.6860 - RootMeanSquaredError: 64.2682 - val_loss: 646.4594 - val_RootMeanSquaredError: 25.4199
# Epoch 183/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4057.2683 - RootMeanSquaredError: 63.6944 - val_loss: 646.5316 - val_RootMeanSquaredError: 25.4213
# Epoch 184/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4105.6068 - RootMeanSquaredError: 64.0728 - val_loss: 646.5976 - val_RootMeanSquaredError: 25.4226
# Epoch 185/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4014.3790 - RootMeanSquaredError: 63.3569 - val_loss: 646.6730 - val_RootMeanSquaredError: 25.4241
# Epoch 186/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4041.2043 - RootMeanSquaredError: 63.5682 - val_loss: 646.7603 - val_RootMeanSquaredError: 25.4258
# Epoch 187/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4066.3579 - RootMeanSquaredError: 63.7657 - val_loss: 646.8322 - val_RootMeanSquaredError: 25.4272
# Epoch 188/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4169.6149 - RootMeanSquaredError: 64.5703 - val_loss: 646.9139 - val_RootMeanSquaredError: 25.4288
# Epoch 189/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4023.3984 - RootMeanSquaredError: 63.4280 - val_loss: 646.9962 - val_RootMeanSquaredError: 25.4305
# Epoch 190/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4131.9298 - RootMeanSquaredError: 64.2778 - val_loss: 647.0637 - val_RootMeanSquaredError: 25.4318
# Epoch 191/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4083.2999 - RootMeanSquaredError: 63.8984 - val_loss: 647.1452 - val_RootMeanSquaredError: 25.4334
# Epoch 192/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 3960.7688 - RootMeanSquaredError: 62.9324 - val_loss: 647.2234 - val_RootMeanSquaredError: 25.4349
# Epoch 193/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4096.6314 - RootMeanSquaredError: 64.0027 - val_loss: 647.2974 - val_RootMeanSquaredError: 25.4364
# Epoch 194/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4038.0848 - RootMeanSquaredError: 63.5437 - val_loss: 647.3746 - val_RootMeanSquaredError: 25.4379
# Epoch 195/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4135.5441 - RootMeanSquaredError: 64.3060 - val_loss: 647.4364 - val_RootMeanSquaredError: 25.4391
# Epoch 196/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4130.4123 - RootMeanSquaredError: 64.2660 - val_loss: 647.5045 - val_RootMeanSquaredError: 25.4404
# Epoch 197/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4181.1095 - RootMeanSquaredError: 64.6593 - val_loss: 647.5771 - val_RootMeanSquaredError: 25.4419
# Epoch 198/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4047.8275 - RootMeanSquaredError: 63.6203 - val_loss: 647.6675 - val_RootMeanSquaredError: 25.4436
# Epoch 199/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 3918.4409 - RootMeanSquaredError: 62.5951 - val_loss: 647.7562 - val_RootMeanSquaredError: 25.4454
# Epoch 200/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4075.4050 - RootMeanSquaredError: 63.8366 - val_loss: 647.8312 - val_RootMeanSquaredError: 25.4469
# Epoch 201/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 4069.7076 - RootMeanSquaredError: 63.7920 - val_loss: 647.9104 - val_RootMeanSquaredError: 25.4484
# Epoch 202/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4003.2961 - RootMeanSquaredError: 63.2693 - val_loss: 647.9952 - val_RootMeanSquaredError: 25.4501
# Epoch 203/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4026.7631 - RootMeanSquaredError: 63.4545 - val_loss: 648.0595 - val_RootMeanSquaredError: 25.4513
# Epoch 204/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4082.7736 - RootMeanSquaredError: 63.8943 - val_loss: 648.1373 - val_RootMeanSquaredError: 25.4529
# Epoch 205/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4100.8462 - RootMeanSquaredError: 64.0356 - val_loss: 648.2150 - val_RootMeanSquaredError: 25.4544
# Epoch 206/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4059.7772 - RootMeanSquaredError: 63.7141 - val_loss: 648.2999 - val_RootMeanSquaredError: 25.4561
# Epoch 207/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4104.7132 - RootMeanSquaredError: 64.0658 - val_loss: 648.3743 - val_RootMeanSquaredError: 25.4575
# Epoch 208/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4000.8266 - RootMeanSquaredError: 63.2498 - val_loss: 648.4496 - val_RootMeanSquaredError: 25.4590
# Epoch 209/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 3952.9426 - RootMeanSquaredError: 62.8701 - val_loss: 648.5237 - val_RootMeanSquaredError: 25.4605
# Epoch 210/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4102.0251 - RootMeanSquaredError: 64.0448 - val_loss: 648.6023 - val_RootMeanSquaredError: 25.4620
# Epoch 211/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4061.3955 - RootMeanSquaredError: 63.7268 - val_loss: 648.6756 - val_RootMeanSquaredError: 25.4634
# Epoch 212/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 3888.0615 - RootMeanSquaredError: 62.3520 - val_loss: 648.7573 - val_RootMeanSquaredError: 25.4651
# Epoch 213/5000
# 397/397 [==============================] - ETA: 0s - loss: 3259.2942 - RootMeanSquaredError: 57.08 - 0s 62us/sample - loss: 4049.6117 - RootMeanSquaredError: 63.6343 - val_loss: 648.8415 - val_RootMeanSquaredError: 25.4667
# Epoch 214/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4023.9476 - RootMeanSquaredError: 63.4323 - val_loss: 648.9298 - val_RootMeanSquaredError: 25.4684
# Epoch 215/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4122.2989 - RootMeanSquaredError: 64.2029 - val_loss: 649.0105 - val_RootMeanSquaredError: 25.4700
# Epoch 216/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4028.9865 - RootMeanSquaredError: 63.4720 - val_loss: 649.0992 - val_RootMeanSquaredError: 25.4718
# Epoch 217/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4062.8079 - RootMeanSquaredError: 63.7379 - val_loss: 649.1614 - val_RootMeanSquaredError: 25.4730
# Epoch 218/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 3939.4233 - RootMeanSquaredError: 62.7625 - val_loss: 649.2488 - val_RootMeanSquaredError: 25.4747
# Epoch 219/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4004.2558 - RootMeanSquaredError: 63.2769 - val_loss: 649.3211 - val_RootMeanSquaredError: 25.4761
# Epoch 220/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4006.8182 - RootMeanSquaredError: 63.2972 - val_loss: 649.4047 - val_RootMeanSquaredError: 25.4778
# Epoch 221/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 3966.0022 - RootMeanSquaredError: 62.9739 - val_loss: 649.4898 - val_RootMeanSquaredError: 25.4794
# Epoch 222/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4082.2836 - RootMeanSquaredError: 63.8905 - val_loss: 649.5576 - val_RootMeanSquaredError: 25.4808
# Epoch 223/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4010.3074 - RootMeanSquaredError: 63.3247 - val_loss: 649.6522 - val_RootMeanSquaredError: 25.4826
# Epoch 224/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4127.1390 - RootMeanSquaredError: 64.2406 - val_loss: 649.7227 - val_RootMeanSquaredError: 25.4840
# Epoch 225/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 4007.4103 - RootMeanSquaredError: 63.3018 - val_loss: 649.8011 - val_RootMeanSquaredError: 25.4855
# Epoch 226/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4182.8547 - RootMeanSquaredError: 64.6728 - val_loss: 649.8813 - val_RootMeanSquaredError: 25.4871
# Epoch 227/5000
# 397/397 [==============================] - 0s 71us/sample - loss: 4019.6127 - RootMeanSquaredError: 63.3981 - val_loss: 649.9649 - val_RootMeanSquaredError: 25.4888
# Epoch 228/5000
# 397/397 [==============================] - 0s 72us/sample - loss: 4093.4361 - RootMeanSquaredError: 63.9777 - val_loss: 650.0343 - val_RootMeanSquaredError: 25.4901
# Epoch 229/5000
# 397/397 [==============================] - 0s 70us/sample - loss: 4096.4220 - RootMeanSquaredError: 64.0010 - val_loss: 650.1083 - val_RootMeanSquaredError: 25.4916
# Epoch 230/5000
# 397/397 [==============================] - 0s 72us/sample - loss: 3992.9142 - RootMeanSquaredError: 63.1872 - val_loss: 650.2009 - val_RootMeanSquaredError: 25.4934
# Epoch 231/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 3986.0105 - RootMeanSquaredError: 63.1326 - val_loss: 650.2921 - val_RootMeanSquaredError: 25.4952
# Epoch 232/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4031.3335 - RootMeanSquaredError: 63.4905 - val_loss: 650.3560 - val_RootMeanSquaredError: 25.4964
# Epoch 233/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4075.3015 - RootMeanSquaredError: 63.8358 - val_loss: 650.4402 - val_RootMeanSquaredError: 25.4981
# Epoch 234/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4189.2028 - RootMeanSquaredError: 64.7218 - val_loss: 650.5056 - val_RootMeanSquaredError: 25.4994
# Epoch 235/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 3997.2515 - RootMeanSquaredError: 63.2215 - val_loss: 650.5963 - val_RootMeanSquaredError: 25.5011
# Epoch 236/5000
# 397/397 [==============================] - 0s 58us/sample - loss: 4025.7520 - RootMeanSquaredError: 63.4465 - val_loss: 650.6835 - val_RootMeanSquaredError: 25.5028
# Epoch 237/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4026.1070 - RootMeanSquaredError: 63.4493 - val_loss: 650.7538 - val_RootMeanSquaredError: 25.5042
# Epoch 238/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4047.2754 - RootMeanSquaredError: 63.6159 - val_loss: 650.8182 - val_RootMeanSquaredError: 25.5055
# Epoch 239/5000
# 397/397 [==============================] - 0s 65us/sample - loss: 4070.2635 - RootMeanSquaredError: 63.7964 - val_loss: 650.8965 - val_RootMeanSquaredError: 25.5070
# Epoch 240/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4036.3272 - RootMeanSquaredError: 63.5298 - val_loss: 650.9772 - val_RootMeanSquaredError: 25.5086
# Epoch 241/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4036.1677 - RootMeanSquaredError: 63.5286 - val_loss: 651.0594 - val_RootMeanSquaredError: 25.5102
# Epoch 242/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 3975.2245 - RootMeanSquaredError: 63.0471 - val_loss: 651.1471 - val_RootMeanSquaredError: 25.5119
# Epoch 243/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4044.5933 - RootMeanSquaredError: 63.5948 - val_loss: 651.2271 - val_RootMeanSquaredError: 25.5135
# Epoch 244/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4013.5745 - RootMeanSquaredError: 63.3505 - val_loss: 651.3103 - val_RootMeanSquaredError: 25.5151
# Epoch 245/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 4067.6007 - RootMeanSquaredError: 63.7755 - val_loss: 651.3983 - val_RootMeanSquaredError: 25.5169
# Epoch 246/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 4113.8488 - RootMeanSquaredError: 64.1370 - val_loss: 651.4754 - val_RootMeanSquaredError: 25.5184
# Epoch 247/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4012.0316 - RootMeanSquaredError: 63.3383 - val_loss: 651.5592 - val_RootMeanSquaredError: 25.5200
# Epoch 248/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4014.9662 - RootMeanSquaredError: 63.3615 - val_loss: 651.6487 - val_RootMeanSquaredError: 25.5218
# Epoch 249/5000
# 397/397 [==============================] - 0s 62us/sample - loss: 3972.1631 - RootMeanSquaredError: 63.0228 - val_loss: 651.7317 - val_RootMeanSquaredError: 25.5234
# Epoch 250/5000
# 397/397 [==============================] - 0s 58us/sample - loss: 4059.0869 - RootMeanSquaredError: 63.7087 - val_loss: 651.8158 - val_RootMeanSquaredError: 25.5250
# Epoch 251/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 3963.4270 - RootMeanSquaredError: 62.9535 - val_loss: 651.9074 - val_RootMeanSquaredError: 25.5268
# Epoch 252/5000
# 397/397 [==============================] - 0s 58us/sample - loss: 3957.7725 - RootMeanSquaredError: 62.9085 - val_loss: 652.0063 - val_RootMeanSquaredError: 25.5288
# Epoch 253/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4107.9992 - RootMeanSquaredError: 64.0914 - val_loss: 652.0789 - val_RootMeanSquaredError: 25.5302
# Epoch 254/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4040.9374 - RootMeanSquaredError: 63.5661 - val_loss: 652.1794 - val_RootMeanSquaredError: 25.5322
# Epoch 255/5000
# 397/397 [==============================] - 0s 60us/sample - loss: 4076.0623 - RootMeanSquaredError: 63.8418 - val_loss: 652.2572 - val_RootMeanSquaredError: 25.5337
# Epoch 256/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4093.3941 - RootMeanSquaredError: 63.9774 - val_loss: 652.3395 - val_RootMeanSquaredError: 25.5353
# Epoch 257/5000
# 397/397 [==============================] - 0s 64us/sample - loss: 4033.0325 - RootMeanSquaredError: 63.5039 - val_loss: 652.4229 - val_RootMeanSquaredError: 25.5369
# Epoch 258/5000
# 397/397 [==============================] - 0s 67us/sample - loss: 3973.6548 - RootMeanSquaredError: 63.0346 - val_loss: 652.5237 - val_RootMeanSquaredError: 25.5389
# Epoch 259/5000
# 397/397 [==============================] - 0s 68us/sample - loss: 4122.7498 - RootMeanSquaredError: 64.2064 - val_loss: 652.6184 - val_RootMeanSquaredError: 25.5408
# Epoch 260/5000
# 397/397 [==============================] - 0s 66us/sample - loss: 4041.9658 - RootMeanSquaredError: 63.5742 - val_loss: 652.7000 - val_RootMeanSquaredError: 25.5423
# Epoch 261/5000
# 397/397 [==============================] - 0s 66us/sample - loss: 4019.0126 - RootMeanSquaredError: 63.3934 - val_loss: 652.8019 - val_RootMeanSquaredError: 25.5443
# Epoch 262/5000
# 397/397 [==============================] - 0s 63us/sample - loss: 4106.9276 - RootMeanSquaredError: 64.0831 - val_loss: 652.8958 - val_RootMeanSquaredError: 25.5462
# Epoch 263/5000
# 397/397 [==============================] - 0s 58us/sample - loss: 4021.8870 - RootMeanSquaredError: 63.4161 - val_loss: 652.9932 - val_RootMeanSquaredError: 25.5481
# Epoch 264/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 4006.4972 - RootMeanSquaredError: 63.2946 - val_loss: 653.0808 - val_RootMeanSquaredError: 25.5498
# Epoch 265/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 3940.2353 - RootMeanSquaredError: 62.7690 - val_loss: 653.1783 - val_RootMeanSquaredError: 25.5517
# Epoch 266/5000
# ...
# Epoch 4913/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 2987.9613 - RootMeanSquaredError: 54.6596 - val_loss: 995.3973 - val_RootMeanSquaredError: 31.5453
# Epoch 4914/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 2948.0701 - RootMeanSquaredError: 54.2935 - val_loss: 995.5088 - val_RootMeanSquaredError: 31.5471
# Epoch 4915/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3015.7456 - RootMeanSquaredError: 54.9132 - val_loss: 995.4469 - val_RootMeanSquaredError: 31.5461
# Epoch 4916/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 3139.4365 - RootMeanSquaredError: 56.0281 - val_loss: 995.4502 - val_RootMeanSquaredError: 31.5461
# Epoch 4917/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3015.9927 - RootMeanSquaredError: 54.9154 - val_loss: 995.4320 - val_RootMeanSquaredError: 31.5459
# Epoch 4918/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3051.7086 - RootMeanSquaredError: 55.2396 - val_loss: 995.4601 - val_RootMeanSquaredError: 31.5463
# Epoch 4919/5000
# 397/397 [==============================] - 0s 58us/sample - loss: 2995.9435 - RootMeanSquaredError: 54.7326 - val_loss: 995.5035 - val_RootMeanSquaredError: 31.5470
# Epoch 4920/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 2886.2879 - RootMeanSquaredError: 53.7215 - val_loss: 995.5759 - val_RootMeanSquaredError: 31.5481
# Epoch 4921/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3032.1862 - RootMeanSquaredError: 55.0626 - val_loss: 995.4119 - val_RootMeanSquaredError: 31.5455
# Epoch 4922/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 3055.1467 - RootMeanSquaredError: 55.2707 - val_loss: 995.4294 - val_RootMeanSquaredError: 31.5458
# Epoch 4923/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3131.6546 - RootMeanSquaredError: 55.9586 - val_loss: 995.4501 - val_RootMeanSquaredError: 31.5461
# Epoch 4924/5000
# 397/397 [==============================] - 0s 58us/sample - loss: 3207.5016 - RootMeanSquaredError: 56.6322 - val_loss: 995.4485 - val_RootMeanSquaredError: 31.5461
# Epoch 4925/5000
# 397/397 [==============================] - 0s 58us/sample - loss: 2950.7605 - RootMeanSquaredError: 54.3182 - val_loss: 995.5441 - val_RootMeanSquaredError: 31.5476
# Epoch 4926/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 2973.3303 - RootMeanSquaredError: 54.5256 - val_loss: 995.5466 - val_RootMeanSquaredError: 31.5477
# Epoch 4927/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3027.1578 - RootMeanSquaredError: 55.0170 - val_loss: 995.5836 - val_RootMeanSquaredError: 31.5483
# Epoch 4928/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 2961.3722 - RootMeanSquaredError: 54.4158 - val_loss: 995.6260 - val_RootMeanSquaredError: 31.5489
# Epoch 4929/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3194.8600 - RootMeanSquaredError: 56.5205 - val_loss: 995.4940 - val_RootMeanSquaredError: 31.5468
# Epoch 4930/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 2986.9410 - RootMeanSquaredError: 54.6502 - val_loss: 995.5419 - val_RootMeanSquaredError: 31.5476
# Epoch 4931/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3176.0705 - RootMeanSquaredError: 56.3541 - val_loss: 995.5246 - val_RootMeanSquaredError: 31.5473
# Epoch 4932/5000
# 397/397 [==============================] - 0s 58us/sample - loss: 2972.8051 - RootMeanSquaredError: 54.5208 - val_loss: 995.5024 - val_RootMeanSquaredError: 31.5470
# Epoch 4933/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 2915.1291 - RootMeanSquaredError: 53.9892 - val_loss: 995.5643 - val_RootMeanSquaredError: 31.5480
# Epoch 4934/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3100.1868 - RootMeanSquaredError: 55.6767 - val_loss: 995.4593 - val_RootMeanSquaredError: 31.5463
# Epoch 4935/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3016.3661 - RootMeanSquaredError: 54.9188 - val_loss: 995.4353 - val_RootMeanSquaredError: 31.5459
# Epoch 4936/5000
# 397/397 [==============================] - 0s 61us/sample - loss: 2920.2434 - RootMeanSquaredError: 54.0366 - val_loss: 995.3754 - val_RootMeanSquaredError: 31.5450
# Epoch 4937/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 3148.8893 - RootMeanSquaredError: 56.1124 - val_loss: 995.3037 - val_RootMeanSquaredError: 31.5438
# Epoch 4938/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 3156.6913 - RootMeanSquaredError: 56.1819 - val_loss: 995.2739 - val_RootMeanSquaredError: 31.5433
# Epoch 4939/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3067.3938 - RootMeanSquaredError: 55.3814 - val_loss: 995.2158 - val_RootMeanSquaredError: 31.5424
# Epoch 4940/5000
# 397/397 [==============================] - 0s 58us/sample - loss: 3093.7711 - RootMeanSquaredError: 55.6191 - val_loss: 995.1691 - val_RootMeanSquaredError: 31.5417
# Epoch 4941/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3087.5569 - RootMeanSquaredError: 55.5632 - val_loss: 995.1092 - val_RootMeanSquaredError: 31.5407
# Epoch 4942/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 3175.0026 - RootMeanSquaredError: 56.3446 - val_loss: 995.0685 - val_RootMeanSquaredError: 31.5401
# Epoch 4943/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 3124.7821 - RootMeanSquaredError: 55.8971 - val_loss: 995.0024 - val_RootMeanSquaredError: 31.5390
# Epoch 4944/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 2962.0732 - RootMeanSquaredError: 54.4223 - val_loss: 995.0024 - val_RootMeanSquaredError: 31.5390
# Epoch 4945/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3071.5089 - RootMeanSquaredError: 55.4186 - val_loss: 994.9270 - val_RootMeanSquaredError: 31.5378
# Epoch 4946/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 2979.6975 - RootMeanSquaredError: 54.5839 - val_loss: 995.0220 - val_RootMeanSquaredError: 31.5394
# Epoch 4947/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 3115.5910 - RootMeanSquaredError: 55.8149 - val_loss: 994.9924 - val_RootMeanSquaredError: 31.5389
# Epoch 4948/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3140.3174 - RootMeanSquaredError: 56.0359 - val_loss: 994.9102 - val_RootMeanSquaredError: 31.5376
# Epoch 4949/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 2973.2380 - RootMeanSquaredError: 54.5247 - val_loss: 994.9161 - val_RootMeanSquaredError: 31.5377
# Epoch 4950/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3154.6536 - RootMeanSquaredError: 56.1637 - val_loss: 994.7704 - val_RootMeanSquaredError: 31.5354
# Epoch 4951/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 3071.5838 - RootMeanSquaredError: 55.4192 - val_loss: 994.7346 - val_RootMeanSquaredError: 31.5348
# Epoch 4952/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3023.7070 - RootMeanSquaredError: 54.9856 - val_loss: 994.7742 - val_RootMeanSquaredError: 31.5354
# Epoch 4953/5000
# 397/397 [==============================] - 0s 53us/sample - loss: 3113.3382 - RootMeanSquaredError: 55.7947 - val_loss: 994.7661 - val_RootMeanSquaredError: 31.5353
# Epoch 4954/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3010.5976 - RootMeanSquaredError: 54.8663 - val_loss: 994.6984 - val_RootMeanSquaredError: 31.5342
# Epoch 4955/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3034.4781 - RootMeanSquaredError: 55.0835 - val_loss: 994.6951 - val_RootMeanSquaredError: 31.5342
# Epoch 4956/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3204.6576 - RootMeanSquaredError: 56.6071 - val_loss: 994.6349 - val_RootMeanSquaredError: 31.5332
# Epoch 4957/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 3015.7895 - RootMeanSquaredError: 54.9136 - val_loss: 994.5771 - val_RootMeanSquaredError: 31.5323
# Epoch 4958/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 2895.0955 - RootMeanSquaredError: 53.8034 - val_loss: 994.6268 - val_RootMeanSquaredError: 31.5331
# Epoch 4959/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3016.1438 - RootMeanSquaredError: 54.9168 - val_loss: 994.6102 - val_RootMeanSquaredError: 31.5328
# Epoch 4960/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 3141.4431 - RootMeanSquaredError: 56.0460 - val_loss: 994.6101 - val_RootMeanSquaredError: 31.5328
# Epoch 4961/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3058.7049 - RootMeanSquaredError: 55.3029 - val_loss: 994.6117 - val_RootMeanSquaredError: 31.5328
# Epoch 4962/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3004.0714 - RootMeanSquaredError: 54.8068 - val_loss: 994.4183 - val_RootMeanSquaredError: 31.5298
# Epoch 4963/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3046.1451 - RootMeanSquaredError: 55.1893 - val_loss: 994.2918 - val_RootMeanSquaredError: 31.5278
# Epoch 4964/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 3041.5440 - RootMeanSquaredError: 55.1476 - val_loss: 994.3125 - val_RootMeanSquaredError: 31.5281
# Epoch 4965/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 2961.0544 - RootMeanSquaredError: 54.4129 - val_loss: 994.2295 - val_RootMeanSquaredError: 31.5268
# Epoch 4966/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 2966.0029 - RootMeanSquaredError: 54.4584 - val_loss: 994.2877 - val_RootMeanSquaredError: 31.5277
# Epoch 4967/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3088.1397 - RootMeanSquaredError: 55.5684 - val_loss: 994.2229 - val_RootMeanSquaredError: 31.5267
# Epoch 4968/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 2944.2908 - RootMeanSquaredError: 54.2586 - val_loss: 994.2707 - val_RootMeanSquaredError: 31.5274
# Epoch 4969/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3021.1042 - RootMeanSquaredError: 54.9619 - val_loss: 994.3162 - val_RootMeanSquaredError: 31.5282
# Epoch 4970/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 3107.6389 - RootMeanSquaredError: 55.7436 - val_loss: 994.2712 - val_RootMeanSquaredError: 31.5275
# Epoch 4971/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 2988.7103 - RootMeanSquaredError: 54.6664 - val_loss: 994.2592 - val_RootMeanSquaredError: 31.5273
# Epoch 4972/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3008.3692 - RootMeanSquaredError: 54.8460 - val_loss: 994.2471 - val_RootMeanSquaredError: 31.5271
# Epoch 4973/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 3127.1492 - RootMeanSquaredError: 55.9183 - val_loss: 994.1527 - val_RootMeanSquaredError: 31.5256
# Epoch 4974/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 3038.7778 - RootMeanSquaredError: 55.1225 - val_loss: 994.1508 - val_RootMeanSquaredError: 31.5255
# Epoch 4975/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 3102.2772 - RootMeanSquaredError: 55.6955 - val_loss: 994.0324 - val_RootMeanSquaredError: 31.5237
# Epoch 4976/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 2996.0972 - RootMeanSquaredError: 54.7340 - val_loss: 994.0576 - val_RootMeanSquaredError: 31.5241
# Epoch 4977/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 2965.6056 - RootMeanSquaredError: 54.4547 - val_loss: 994.0819 - val_RootMeanSquaredError: 31.5244
# Epoch 4978/5000
# 397/397 [==============================] - 0s 53us/sample - loss: 3117.6454 - RootMeanSquaredError: 55.8333 - val_loss: 993.9885 - val_RootMeanSquaredError: 31.5230
# Epoch 4979/5000
# 397/397 [==============================] - 0s 57us/sample - loss: 3144.4052 - RootMeanSquaredError: 56.0724 - val_loss: 993.9707 - val_RootMeanSquaredError: 31.5227
# Epoch 4980/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3146.5581 - RootMeanSquaredError: 56.0916 - val_loss: 993.9075 - val_RootMeanSquaredError: 31.5217
# Epoch 4981/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 2960.6578 - RootMeanSquaredError: 54.4093 - val_loss: 993.9416 - val_RootMeanSquaredError: 31.5222
# Epoch 4982/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 3108.0753 - RootMeanSquaredError: 55.7475 - val_loss: 993.9496 - val_RootMeanSquaredError: 31.5224
# Epoch 4983/5000
# 397/397 [==============================] - 0s 53us/sample - loss: 3112.6965 - RootMeanSquaredError: 55.7889 - val_loss: 993.8613 - val_RootMeanSquaredError: 31.5209
# Epoch 4984/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 3089.2851 - RootMeanSquaredError: 55.5787 - val_loss: 993.7996 - val_RootMeanSquaredError: 31.5200
# Epoch 4985/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 2884.1575 - RootMeanSquaredError: 53.7016 - val_loss: 993.8168 - val_RootMeanSquaredError: 31.5202
# Epoch 4986/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3155.6607 - RootMeanSquaredError: 56.1727 - val_loss: 993.6730 - val_RootMeanSquaredError: 31.5180
# Epoch 4987/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 3089.4656 - RootMeanSquaredError: 55.5803 - val_loss: 993.6422 - val_RootMeanSquaredError: 31.5175
# Epoch 4988/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 3065.0077 - RootMeanSquaredError: 55.3599 - val_loss: 993.6360 - val_RootMeanSquaredError: 31.5174
# Epoch 4989/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 3036.5120 - RootMeanSquaredError: 55.1019 - val_loss: 993.5650 - val_RootMeanSquaredError: 31.5162
# Epoch 4990/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 3112.2185 - RootMeanSquaredError: 55.7847 - val_loss: 993.5360 - val_RootMeanSquaredError: 31.5158
# Epoch 4991/5000
# 397/397 [==============================] - 0s 53us/sample - loss: 3133.7026 - RootMeanSquaredError: 55.9769 - val_loss: 993.4986 - val_RootMeanSquaredError: 31.5152
# Epoch 4992/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 2966.1641 - RootMeanSquaredError: 54.4598 - val_loss: 993.4631 - val_RootMeanSquaredError: 31.5146
# Epoch 4993/5000
# 397/397 [==============================] - 0s 58us/sample - loss: 3002.7094 - RootMeanSquaredError: 54.7943 - val_loss: 993.4205 - val_RootMeanSquaredError: 31.5140
# Epoch 4994/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 2966.0402 - RootMeanSquaredError: 54.4587 - val_loss: 993.3135 - val_RootMeanSquaredError: 31.5123
# Epoch 4995/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3000.1950 - RootMeanSquaredError: 54.7714 - val_loss: 993.3153 - val_RootMeanSquaredError: 31.5123
# Epoch 4996/5000
# 397/397 [==============================] - 0s 54us/sample - loss: 3143.7804 - RootMeanSquaredError: 56.0668 - val_loss: 993.2705 - val_RootMeanSquaredError: 31.5116
# Epoch 4997/5000
# 397/397 [==============================] - 0s 55us/sample - loss: 2878.2161 - RootMeanSquaredError: 53.6463 - val_loss: 993.3262 - val_RootMeanSquaredError: 31.5125
# Epoch 4998/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 2956.5417 - RootMeanSquaredError: 54.3714 - val_loss: 993.3802 - val_RootMeanSquaredError: 31.5133
# Epoch 4999/5000
# 397/397 [==============================] - 0s 56us/sample - loss: 3217.8674 - RootMeanSquaredError: 56.7237 - val_loss: 993.2327 - val_RootMeanSquaredError: 31.5110
# Epoch 5000/5000
# 397/397 [==============================] - 0s 59us/sample - loss: 3036.2913 - RootMeanSquaredError: 55.0999 - val_loss: 993.2312 - val_RootMeanSquaredError: 31.5110
# Average test loss:  3328.4128294534753

# %%
limit = -1
y_pred = model.predict(x_test)
x = range(len(y_pred))
plt.plot(x[:limit],y_pred[:limit],label = 'pred')
plt.plot(x[:limit],y_test[:limit], label = 'test')
plt.legend(fontsize=20)

# %%
limit = -1
y_pred = model.predict(x_test)
x = range(len(y_pred))
plt.plot(x[:limit],y_pred[:limit],label = 'pred')
plt.plot(x[:limit],y_test[:limit], label = 'test')
plt.legend(fontsize=20)

# %%
y_pred = model.predict(x_test)
x = range(len(y_pred))
plt.plot(x,y_pred,label = 'pred')
plt.plot(x,y_test, label = 'test')
plt.legend(fontsize=20)

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 949.3764036956628

# %%
y_pred = model.predict(x_test)

# %%
x = range(len(y_pred))
plt.plot(x,y_pred,label = 'pred')
plt.plot(x,y_test, label = 'test')
plt.legend(fontsize=20)

# %%
x = range(len(y_pred))
plt.plot(x,y_test, label = 'test')
plt.legend(fontsize=20)

# %%
# %tensorboard --logdir logs/scalars
# Out:
#       <iframe id="tensorboard-frame-81ca55e2c4c0703a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-81ca55e2c4c0703a");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
